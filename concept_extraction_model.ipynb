# %% [markdown]
# **set up environment:**

# %%
# !rm -rf half-distant-labeled-datas/ distant-labeled-datas/ test-datas/ train-datas/ val-datas/

# !unzip final_slides_test.zip -d test-datas
# !unzip final_slides_train.zip -d train-datas
# !unzip final_slides_val.zip -d val-datas
# !unzip final_slides_json_distant.zip -d distant-labeled-datas
# !unzip final_slides_json_distant_half.zip -d half-distant-labeled-datas

# !rm -rf self-datas-1/ self-datas-2/

# !unzip final_slides_self_train_1.zip -d self-datas-1
# !unzip final_slides_self_train_2.zip -d self-datas-2
# Out:
# Archive:  final_slides_test.zip
#    creating: test-datas/final_slides_test/
#    creating: test-datas/final_slides_test/CS-0441 Lecture Slides/
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec17.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec18.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec19.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec20.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec21.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec22.json
#   inflating: test-datas/final_slides_test/CS-0441 Lecture Slides/lec23.json
# Archive:  final_slides_train.zip
#    creating: train-datas/final_slides_train/
#    creating: train-datas/final_slides_train/CS-0449 Lecture Slides/
#   inflating: train-datas/final_slides_train/CS-0449 Lecture Slides/01_CS449_Introduction.json
#   inflating: train-datas/final_slides_train/CS-0449 Lecture Slides/02_CS449_Data-Representation.json
#   inflating: train-datas/final_slides_train/CS-0449 Lecture Slides/06_CS449_Memory-Management.json
#    creating: train-datas/final_slides_train/CS-1541 Lecture Notes/
#    creating: train-datas/final_slides_train/CS-1567 Lecture Notes/
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/02_introduction_ros_handout.json
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/03_publisher_subscriber_handout.json
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/07_kobuki_node_handout.json
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/09_10_blobs_detections_handout.json
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/14_pid_control_handout.json
#   inflating: train-datas/final_slides_train/CS-1567 Lecture Notes/15_launch_file_handout.json
#    creating: train-datas/final_slides_train/CS-0441 Lecture Slides/
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec10.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec11.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec12.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec13.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec14.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec15.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec16.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec01.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec02.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec04.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec03.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec05.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec06.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec07.json
#   inflating: train-datas/final_slides_train/CS-0441 Lecture Slides/lec08.json
# Archive:  final_slides_val.zip
#    creating: val-datas/final_slides_val/
#    creating: val-datas/final_slides_val/CS-0441 Lecture Slides/
#   inflating: val-datas/final_slides_val/CS-0441 Lecture Slides/lec09.json
#    creating: val-datas/final_slides_val/CS-0449 Lecture Slides/
#   inflating: val-datas/final_slides_val/CS-0449 Lecture Slides/05_CS449_Introduction-to-Memory.json
#    creating: val-datas/final_slides_val/CS-1541 Lecture Notes/
#   inflating: val-datas/final_slides_val/CS-1541 Lecture Notes/CS1541_Lecture1.1_Introduction.json
#    creating: val-datas/final_slides_val/CS-1567 Lecture Notes/
#   inflating: val-datas/final_slides_val/CS-1567 Lecture Notes/05_joy_node_handout.json
# Archive:  final_slides_json_distant.zip
#    creating: distant-labeled-datas/final_slides_json_distant/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-0441 Lecture Slides/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/03_CS449_Data-Representation-II.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/04_CS449_Introduction-to-C.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/07_CS449_Introduction-to-x86.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/08_CS449_Investigating-the-Code.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/09_CS449_buffer-overflow.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/10_CS449_How-Programs-Are-Made.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/11_CS449_How-Programs-Are-Managed.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/12_CS449_How-Programs-Reproduce.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/13_CS449_Virtual-Memory.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/14_CS449_The-Memory-Hierarchy.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/15_CS449_Threads-and-Synchronization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/16-netprog.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/17_CS449_Files-and-Directories.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/final-review.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/midterm-review.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.2_Technology_Advances.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.3_Technology_Constraints.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.1_Processor_Review.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.2_Processor_Pipelining.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.3_Optimizing_Pipeline_Hazards.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.4_Branch_Prediction.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.5_VLIW_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.6_Superscalar_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.1_Memory_Hierarchy.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.2_Cache_Design.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.3_Cache_Design2.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.4_Virtual_Memory.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.5_Multi_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.6_SIMD_And_GPUs.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture0.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture1.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture10.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture11.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture12.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture13.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture14.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture15.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture16.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture17.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture18.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture19.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture2.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture20.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture21.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture22.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture23.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture24.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture25.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture26.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture27.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture3.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture4.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5-Sherif’s MacBook Pro.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture6.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture7.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture8.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture9.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1567 Lecture Notes/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/01 - Intro and Rust.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/02 - Rust, Strings, and Text.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/03 - Lexing and Grammars.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04 - CFGs and ASTs.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05 - Top-down Parsing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06 - Bottom-up Parsing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07 - Semantic Analysis.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08 - Scoping and Naming.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/09 - Typing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/10 - Advanced Typing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/11 - Backend and Runtime.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/12 - Dynamic Memory Management.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/13 - ABI and Codegen.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/14 - More Codegen and Arrays.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/15 - Structs and Classes, OOP.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/16 - Control Flow Graphs and IR.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/17 - Local Optimization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/18 - Global Optimization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/19 - Liveness and Register Allocation.json
# Archive:  final_slides_json_distant_half.zip
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0441 Lecture Slides/
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/03_CS449_Data-Representation-II.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/04_CS449_Introduction-to-C.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/07_CS449_Introduction-to-x86.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/08_CS449_Investigating-the-Code.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/09_CS449_buffer-overflow.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/10_CS449_How-Programs-Are-Made.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/11_CS449_How-Programs-Are-Managed.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-0449 Lecture Slides/12_CS449_How-Programs-Reproduce.json
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture2.6_Superscalar_Processors.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.1_Memory_Hierarchy.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.2_Cache_Design.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.3_Cache_Design2.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.4_Virtual_Memory.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.5_Multi_Processors.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1541 Lecture Notes/CS1541_Lecture3.6_SIMD_And_GPUs.json
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture13.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture14.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture15.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture16.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture17.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture18.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture19.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture20.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture21.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture22.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture23.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture24.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture25.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture26.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1550 Lecture Slides/Lecture27.json
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1567 Lecture Notes/
#    creating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/01 - Intro and Rust.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/02 - Rust, Strings, and Text.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/03 - Lexing and Grammars.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/04 - CFGs and ASTs.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/05 - Top-down Parsing.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/06 - Bottom-up Parsing.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/07 - Semantic Analysis.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/08 - Scoping and Naming.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/09 - Typing.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/10 - Advanced Typing.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/11 - Backend and Runtime.json
#   inflating: half-distant-labeled-datas/final_slides_json_distant_half/CS-1622 Lecture Slides/12 - Dynamic Memory Management.json
# Archive:  final_slides_self_train_1.zip
#    creating: self-datas-1/final_slides_self_train_1/
#    creating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/01-Introduction.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/02-Binary-Hex-and-Arbitrariness.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/03-Programs-Instructions-and-Registers.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/04-Memory-and-Addresses.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/05-Arrays.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/06-Flow,-Conditionals,-and-Loops.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/07-Functions-and-the-Stack.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/08-Bitwise-Operations.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/09-Addition-Signed-Numbers-and-Overflow.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/10-Fractional binary.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/11-Multiplication_and_Division.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/12-Logic.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/13-Logic-arithmetic-and-Plexers.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/14-Minimization-and-Karnaught.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/15-Latches.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/16-ALU.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/17-FSM.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/18-Controlling-the-PC.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/19-Decoding-and-Control.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/20-Bringing-all-together.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/21-Multicycle-CPU.json
#   inflating: self-datas-1/final_slides_self_train_1/CS-0447 Lecture Slides/22-Pipelining.json
# Archive:  final_slides_self_train_2.zip
#    creating: self-datas-2/final_slides_self_train_2/
#    creating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/0 - cs1502_syllabus_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/10 - turing_machine_02_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/11 - turing_machine_03_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/12-5 - exam_01_review_hanbdout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/12 - turing_machine_04_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/13 - decidability_01_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/14  - decidability_02_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/15 - decidability_03_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/16 - decidability_04_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/17 - decidability_05_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/18 - reducibility_01_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/19 - reducibility_02_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/1 - math_prelim_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/20 - reducibility_as_methods_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/21 - reducibility_04_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/22 - reducibility_05_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/23 - reducibility_06_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/24 - pcp_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/25 - reducibility_08_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/26 - time_complexity_01_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/27 - time_complexity_02_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/28 - time_complexity_03_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/29 - time_complexity_04_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/2 - finite_automata_01_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/30 - spring_2021_final_review_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/3 - finite_automata_02_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/4 - finite_automata_03_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/5 - finite_automata_04_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/6 - finite_automata_05_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/7 - finite_automata_06_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/8 - finite_automata_07_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/9 - turing_machine_01_handout.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/practice_fsm.json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/Whiteboard[2] (1).json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/Whiteboard[2].json
#   inflating: self-datas-2/final_slides_self_train_2/CS-1502 Lecture Slides/Whiteboard[4].json

# %%
# !pip install transformers seqeval[gpu]
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.dummy import DummyClassifier
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import XLNetTokenizer, XLNetConfig, XLNetForTokenClassification
from transformers import BertTokenizer, BertConfig, BertForTokenClassification
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
import json
import os
import random
from seqeval.metrics import classification_report

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(0)

# %%
from pathlib import Path
import itertools

train_path = 'train-datas'
val_path = 'val-datas'
test_path = 'test-datas'
distant_label_dir_path = 'distant-labeled-datas'
half_distant_label_dir_path = 'half-distant-labeled-datas'
self_label_1_path = 'self-datas-1'
self_label_2_path = 'self-datas-2'
is_flat = False
window = False
is_distant_label = False
is_half_distant_label = False
is_validation = True
WINDOW_SIZE=1
#model_type = 'BERT'
model_type = 'XLNet'

class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

def get_data(data_path):
  sentences = []
  labels = []
  for dir in Path(data_path).glob('*'):
    for filename in Path(dir).glob('**/*.json'):
        path = filename
        if os.path.isfile(path):
          f = open(path)
          print(path, f)
          file_data = json.load(f)
          if not is_flat:
            if not window:
              for item in file_data:
                sentences.append(item['words'])
                labels.append(item['labels'])
            else:
              for i in range(len(file_data)):
                window_words = []
                window_labels = []
                for item in file_data[i:i+WINDOW_SIZE]:
                  window_words.extend(item['words'])
                  window_labels.extend(item['labels'])
                sentences.append(window_words)
                labels.append(window_labels)
          else:
            sentences.append(file_data['words'])
            labels.append(file_data['labels'])
  return (sentences, labels)

def get_eval_data(data_path):
  sentences = dict()
  labels = dict()
  for dir in Path(data_path).glob('*'):
    for filename in Path(dir).glob('**/*.json'):
        path = filename
        if os.path.isfile(path):
          f = open(path)
          print(path, f)
          file_data = json.load(f)
          sentences[Path(path).stem] = []
          labels[Path(path).stem] = []
          for item in file_data:
            sentences[Path(path).stem].append(item['words'])
            labels[Path(path).stem].append(item['labels'])
  return sentences, labels


sentences, labels = get_data(test_path)
test_dataset = pd.DataFrame({'sentence': sentences, 'word_labels': labels})
sentences, labels = get_eval_data(test_path)
test_block_datasets = [pd.DataFrame(({'sentence': sentences[file], 'word_labels': labels[file]})) for file in sentences]
print(test_block_datasets)
sentences, labels = get_data(train_path)
train_dataset = pd.DataFrame({'sentence': sentences, 'word_labels': labels})
sentences, labels = get_data(val_path)
validation_dataset = pd.DataFrame({'sentence': sentences, 'word_labels': labels})
sentences, labels = get_data(self_label_1_path)
self_training_dataset_1 = pd.DataFrame({'sentence': sentences, 'word_labels': labels})
sentences, labels = get_data(self_label_2_path)
self_training_dataset_2 = pd.DataFrame({'sentence': sentences, 'word_labels': labels})
if is_distant_label:
  d_sentences, d_labels = get_data(distant_label_dir_path)
  d_data = pd.DataFrame({'sentence': d_sentences, 'word_labels': d_labels})
  print(d_data)

if is_half_distant_label:
  d_sentences, d_labels = get_data(half_distant_label_dir_path)
  d_data = pd.DataFrame({'sentence': d_sentences, 'word_labels': d_labels})
  print(d_data)

print(train_dataset)
print(validation_dataset)
print(test_dataset)

#train_size = 0.8
#train_dataset = big_train_dataset.sample(frac=train_size,random_state=200)
#validation_dataset = big_train_dataset.drop(train_dataset.index).reset_index(drop=True)
#train_dataset, validation_dataset = np.split(big_train_dataset, [int(train_size*len(big_train_dataset))])
#validation_dataset = validation_dataset.reset_index(drop=True)
if is_distant_label or is_half_distant_label:
  train_dataset = pd.concat([train_dataset, d_data])
  pass
if not is_validation:
  train_dataset = pd.concat([train_dataset, validation_dataset])
train_dataset = train_dataset.reset_index(drop=True)
self_training_dataset = pd.concat([self_training_dataset_1, self_training_dataset_2])
self_training_dataset = self_training_dataset.reset_index(drop=True)

print("TRAIN Dataset: {}".format(train_dataset.shape))
print("VAL Dataset: {}".format(validation_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))

# %% [markdown]
# **preparing dataset and dataloader:**

# %%
import math
import copy

MAX_LEN = 512
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2
EPOCHS = 50
LEARNING_RATE = 1e-05
MAX_GRAD_NORM = 10
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased') if model_type == 'XLNet' else BertTokenizer.from_pretrained('bert-base-uncased')
CLS_TOKEN = "<cls>" if model_type == 'XLNet' else "[CLS]"
SEP_TOKEN = "<sep>" if model_type == 'XLNet' else "[SEP]"
PAD_TOKEN = "<pad>" if model_type == 'XLNet' else "[PAD]"

label2id = {
    'B': 0,
    'I': 1,
    'O': 2
 }
id2label = {
    0: 'B',
    1: 'I',
    2: 'O'
}

def tokenize_and_preserve_labels(sentence, text_labels, tokenizer):
    """
    Word piece tokenization makes it difficult to match word labels
    back up with individual word pieces. This function tokenizes each
    word one at a time so that it is easier to preserve the correct
    label for each subword. It is, of course, a bit slower in processing
    time, but it will help our model achieve higher accuracy.
    """

    tokenized_sentence = []
    labels = []

    for word, label in zip(sentence, text_labels):

        # Tokenize the word and count # of subwords the word is broken into
        tokenized_word = tokenizer.tokenize(word)
        n_subwords = len(tokenized_word)

        # Add the tokenized word to the final tokenized word list
        tokenized_sentence.extend(tokenized_word)

        # Add the same label to the new list of labels `n_subwords` times
        labels.extend([label] * n_subwords)

    return tokenized_sentence, labels

class dataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len, model=None, model_name=""):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.model = model
        self.model_name = model_name

    def set_model(self, model, model_name=""):
        del self.model
        torch.cuda.empty_cache()
        self.model = copy.deepcopy(model)
        self.model_name = model_name

    def __getitem__(self, index):
        # step 1: tokenize (and adapt corresponding labels)
        sentence = self.data.sentence[index]
        word_labels = self.data.word_labels[index]
        tokenized_sentence, labels = tokenize_and_preserve_labels(sentence, word_labels, self.tokenizer)

        # step 2: add special tokens (and corresponding labels)
        tokenized_sentence = tokenized_sentence + [SEP_TOKEN] + [CLS_TOKEN] if model_type =='XLNet' else [CLS_TOKEN] + tokenized_sentence + [SEP_TOKEN] # add special tokens
        if model_type == "XLNet":
          labels.append("O") # add outside label for [SEP] token
          labels.append("O") # add outside label for [CLS] token
        else:
          labels.insert(0, "O") # add outside label for [CLS] token
          labels.append("O") # add outside label for [SEP] token

        # step 3: truncating/padding
        maxlen = self.max_len

        if (len(tokenized_sentence) > maxlen):
          # truncate
          tokenized_sentence = tokenized_sentence[:maxlen]
          labels = labels[:maxlen]
        else:
          # pad
          tokenized_sentence = tokenized_sentence + [PAD_TOKEN for _ in range(maxlen - len(tokenized_sentence))]
          labels = labels + ["O" for _ in range(maxlen - len(labels))]

        # step 4: obtain the attention mask
        attn_mask = [1 if tok != PAD_TOKEN else 0 for tok in tokenized_sentence]

        # step 5: convert tokens to input ids
        ids = self.tokenizer.convert_tokens_to_ids(tokenized_sentence)

        label_ids = [label2id[label] for label in labels]

        if self.model is not None:
          self.model.eval()
          ids_t = torch.tensor(ids, dtype=torch.long).unsqueeze(0).to(device)
          mask_t = torch.tensor(attn_mask, dtype=torch.long).unsqueeze(0).to(device)
          label_ids_t =  torch.tensor(label_ids, dtype=torch.long).unsqueeze(0).to(device)
          outputs = self.model(input_ids=ids_t, attention_mask=mask_t, labels=label_ids_t)
          loss, eval_logits = outputs.loss, outputs.logits

          active_logits = eval_logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
          flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
          # now, use mask to determine where we should compare predictions with targets (includes [CLS] and [SEP] token predictions)
          # active_accuracy = mask_t.view(-1) == 1 # active accuracy is also of shape (batch_size * seq_len,)
          # prediction_ids = torch.masked_select(flattened_predictions, active_accuracy)
          prediction_ids = flattened_predictions
        else:
          prediction_ids = [label2id['O'] for label in labels]
        # the following line is deprecated
        #label_ids = [label if label != 0 else -100 for label in label_ids]

        return {
              'ids': torch.tensor(ids, dtype=torch.long),
              'mask': torch.tensor(attn_mask, dtype=torch.long),
              #'token_type_ids': torch.tensor(token_ids, dtype=torch.long),
              'targets': torch.tensor(label_ids, dtype=torch.long),
              'predictions': prediction_ids
        }

    def __len__(self):
        return self.len

    def __iter__(self):
        worker_info = torch.utils.data.get_worker_info()
        if worker_info is None:
            return map(self.__getitem__, range(self.__len__()))

        per_worker = int(math.ceil((self.__len__()) / float(worker_info.num_workers)))
        worker_id = worker_info.id
        iter_start = worker_id * per_worker
        iter_end = min(iter_start + per_worker, self.__len__())
        return map(self.__getitem__, range(iter_start, iter_end))

training_set = dataset(train_dataset, tokenizer, MAX_LEN)
self_training_set_1 = dataset(self_training_dataset_1, tokenizer, MAX_LEN)
self_training_set_2 = dataset(self_training_dataset_2, tokenizer, MAX_LEN)
self_training_set = dataset(self_training_dataset, tokenizer, MAX_LEN)
validation_set = dataset(validation_dataset, tokenizer, MAX_LEN)
testing_set = dataset(test_dataset, tokenizer, MAX_LEN)
test_block_set = [dataset(data_set, tokenizer, MAX_LEN) for data_set in test_block_datasets]

# print the first 30 tokens and corresponding labels
for token, label in zip(tokenizer.convert_ids_to_tokens(training_set[0]["ids"][:30]), training_set[0]["targets"][:30]):
  print('{0:10}  {1}'.format(token, id2label[label.item()]))


train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

valid_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': 1,
                'shuffle': False,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
self_training_loader_1 = DataLoader(self_training_set_1, **train_params)
self_training_loader_2 = DataLoader(self_training_set_2, **train_params)
self_training_loader = DataLoader(self_training_set, **train_params)
validation_loader = DataLoader(validation_set, **valid_params)
testing_loader = DataLoader(testing_set, **test_params)
test_block_loader = [DataLoader(data_set, **test_params) for data_set in test_block_set]

# %% [markdown]
# **defining the model:**

# %%
if model_type == 'XLNet':
  model = XLNetForTokenClassification.from_pretrained('xlnet-base-cased',
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
else:
  model = BertForTokenClassification.from_pretrained('bert-base-uncased',
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
model.to(device)

# %% [markdown]
# **training the model:**

# %%
#ids = training_set[0]["ids"].unsqueeze(0)
#mask = training_set[0]["mask"].unsqueeze(0)
#targets = training_set[0]["targets"].unsqueeze(0)
#ids = ids.to(device)
#mask = mask.to(device)
#targets = targets.to(device)
#outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
#initial_loss = outputs[0]
#tr_logits = outputs[1]
model_reload=True
if model_reload:
  model = XLNetForTokenClassification.from_pretrained("AwesomeREK/concept-extraction-xlnet-early-stopping",
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
model.to(device)
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

def get_chunks(seq):
    """
    Adapted from BOND paper
    """
    chunks = []

    chunk_start = None
    for i, tok in enumerate(seq):
        if tok == "O" and chunk_start is not None:
            chunk = (chunk_start, i)
            chunks.append(chunk)
            chunk_start = None
        if tok == "B":
            if chunk_start is not None:
                chunk = (chunk_start, i)
                chunks.append(chunk)
            chunk_start=i
    if chunk_start is not None:
        chunk = (chunk_start, len(seq))
        chunks.append(chunk)
    return chunks

# Defining the training function on the 80% of the dataset for tuning the xlnet model
def train(model, optimizer, loader, epoch, gold=True):
    tr_loss, tr_accuracy = 0, 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    field = 'targets' if gold else 'predictions'
    # put model in training mode
    model.train()

    for idx, batch in enumerate(loader):

        ids = batch['ids'].to(device, dtype = torch.long)
        mask = batch['mask'].to(device, dtype = torch.long)
        targets = batch[field].to(device, dtype = torch.long)

        outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
        loss, tr_logits = outputs.loss, outputs.logits
        tr_loss += loss.item()

        nb_tr_steps += 1
        nb_tr_examples += targets.size(0)

        if idx % 100==0:
            loss_step = tr_loss/nb_tr_steps
            print(f"Training loss per 100 training steps: {loss_step}")

        # compute training accuracy
        flattened_targets = targets.view(-1) # shape (batch_size * seq_len,)
        active_logits = tr_logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
        # now, use mask to determine where we should compare predictions with targets (includes [CLS] and [SEP] token predictions)
        active_accuracy = mask.view(-1) == 1 # active accuracy is also of shape (batch_size * seq_len,)
        targets = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_preds.extend(predictions)
        tr_labels.extend(targets)

        tmp_tr_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=MAX_GRAD_NORM
        )

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    print(f"Training loss epoch: {epoch_loss}")
    print(f"Training accuracy epoch: {tr_accuracy}")

from time import sleep
def valid(model, loader):
    # put model in evaluation mode
    model.eval()

    eval_loss, eval_accuracy = 0, 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []

    with torch.no_grad():
        for idx, batch in enumerate(loader):

            ids = batch['ids'].to(device, dtype = torch.long)
            mask = batch['mask'].to(device, dtype = torch.long)
            targets = batch['targets'].to(device, dtype = torch.long)

            outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
            loss, eval_logits = outputs.loss, outputs.logits

            eval_loss += loss.item()

            nb_eval_steps += 1
            nb_eval_examples += targets.size(0)

            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")

            # compute evaluation accuracy
            flattened_targets = targets.view(-1) # shape (batch_size * seq_len,)
            active_logits = eval_logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
            # now, use mask to determine where we should compare predictions with targets (includes [CLS] and [SEP] token predictions)
            active_accuracy = mask.view(-1) == 1 # active accuracy is also of shape (batch_size * seq_len,)
            targets = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)

            eval_labels.extend(targets)
            eval_preds.extend(predictions)

            tmp_eval_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy

    #print(eval_labels)
    #print(eval_preds)

    labels = [id2label[id.item()] for id in eval_labels]
    predictions = [id2label[id.item()] for id in eval_preds]

    #print(labels)
    #print(predictions)

    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps

    label_chunks, pred_chunks = set(get_chunks(labels)), set(get_chunks(predictions))
    print(label_chunks)
    print(pred_chunks)
    correct_preds = len(label_chunks & pred_chunks)
    total_preds = len(pred_chunks)
    total_correct = len(label_chunks)

    p   = correct_preds / total_preds if correct_preds > 0 else 0
    r   = correct_preds / total_correct if correct_preds > 0 else 0
    new_F  = 2 * p * r / (p + r) if correct_preds > 0 else 0

    print(f"Validation Loss: {eval_loss}")
    print(f"Validation Accuracy: {eval_accuracy}")
    print(f"Chunk Precision: {p}")
    print(f"Chunk Recall: {r}")
    print(f"Chunk F1: {new_F}")

    return eval_loss, labels, predictions

def train_epochs(model, optimizer, train_loader, dev_loader, num_epochs):
  early_stopper = EarlyStopper(patience=5, min_delta=0.01)
  for epoch in range(num_epochs):
    print(f"Training epoch: {epoch + 1}")
    train(model, optimizer, train_loader, epoch)
    if is_validation:
      loss, labels, predictions = valid(model, dev_loader)
      print(classification_report([labels], [predictions]))
      if early_stopper.early_stop(loss):
        break
    loss, labels, predictions = valid(model, testing_loader)
    print(classification_report([labels], [predictions]))

if not model_reload:
  train_epochs(model, optimizer, training_loader, validation_loader, EPOCHS)
# Out:
# Training epoch: 1
# Training loss per 100 training steps: 3.6240651607513428
# Training loss per 100 training steps: 0.22154512774604973
# Training loss epoch: 0.15658160727074805
# Training accuracy epoch: 0.8790059430434554
# Validation loss per 100 evaluation steps: 0.024863142520189285
# Validation loss per 100 evaluation steps: 0.05877726149369529
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(5681, 5682), (29245, 29246), (27230, 27231), (26188, 26189), (28089, 28090), (21465, 21466), (5502, 5503), (26189, 26190), (27910, 27911), (26184, 26185), (18377, 18378), (29278, 29279), (27231, 27232), (29255, 29256), (4327, 4328), (4970, 4971), (26286, 26287), (26896, 26897), (26190, 26191), (25639, 25640), (29311, 29312), (4305, 4306), (5219, 5220), (8409, 8410), (26897, 26898), (25635, 25636), (7987, 7988), (27999, 28000), (29252, 29253), (29229, 29230), (25640, 25641), (262, 263), (8442, 8443), (24938, 24939), (25613, 25614), (4307, 4308), (5224, 5225), (25608, 25609), (29230, 29231), (14721, 14722), (16080, 16081), (29312, 29313), (25609, 25610), (4587, 4588), (28000, 28001), (25646, 25647), (26289, 26290), (29253, 29254), (27110, 27111), (25761, 25762), (26743, 26744), (14580, 14581), (26808, 26809), (29300, 29301), (26069, 26070), (4308, 4309), (29296, 29297), (21328, 21329), (4561, 4562), (29291, 29292), (27974, 27975), (6829, 6830), (8137, 8138), (26047, 26048), (7705, 7706), (26313, 26314), (5723, 5724), (25680, 25681), (26043, 26044), (25611, 25612), (26809, 26810), (8211, 8212), (4227, 4228), (26070, 26071), (19172, 19173), (25607, 25608), (4191, 4192), (19521, 19522), (27232, 27233), (4223, 4224), (25612, 25613), (26810, 26811), (26071, 26072), (26048, 26049), (16937, 16938), (25681, 25682), (19205, 19206), (18411, 18412), (4224, 4225), (6826, 6827), (21330, 21331), (5261, 5262), (26044, 26045), (25645, 25646), (27981, 27982), (4306, 4307), (26898, 26899), (18407, 18408), (27206, 27207), (4408, 4409), (6827, 6828), (18389, 18390), (26288, 26289), (27918, 27919), (8388, 8389), (19179, 19180), (4188, 4189), (29231, 29232), (16081, 16082), (7993, 7994), (4386, 4387), (18412, 18413), (26078, 26079), (27909, 27910), (27221, 27222), (27919, 27920), (27207, 27208), (18845, 18846), (5484, 5485), (6828, 6829), (26046, 26047), (5727, 5728), (19515, 19516), (22760, 22761), (26744, 26745), (5732, 5733), (19180, 19181), (26791, 26792), (15504, 15505), (26079, 26080), (29279, 29280), (25777, 25778), (4222, 4223), (26879, 26880), (7688, 7689), (15505, 15506), (25653, 25654), (26080, 26081), (5706, 5707), (27926, 27927), (4324, 4325), (18328, 18329), (21734, 21735), (4228, 4229), (7790, 7791), (27219, 27220), (26912, 26913), (120, 121), (5513, 5514), (4325, 4326), (27954, 27955), (14648, 14649), (25682, 25683), (26054, 26055), (16094, 16095), (27927, 27928), (25880, 25881), (26940, 26941), (6832, 6833), (5676, 5677), (25779, 25780), (29240, 29241), (5487, 5488), (4409, 4410), (26913, 26914), (29277, 29278), (26762, 26763), (27955, 27956), (26083, 26084), (27226, 27227), (5704, 5705), (4387, 4388), (4226, 4227), (26185, 26186), (27222, 27223), (25634, 25635), (7784, 7785), (28296, 28297), (27108, 27109), (18391, 18392), (26796, 26797), (27984, 27985), (4296, 4297), (17079, 17080), (5494, 5495), (26310, 26311), (18397, 18398), (4388, 4389), (25759, 25760), (16093, 16094), (14601, 14602), (29280, 29281), (26182, 26183), (29317, 29318), (8011, 8012), (25760, 25761), (25654, 25655), (27229, 27230), (8470, 8471), (19261, 19262), (23672, 23673), (20886, 20887), (29313, 29314), (26311, 26312), (5221, 5222), (26899, 26900), (8195, 8196), (18398, 18399), (27220, 27221), (25783, 25784), (27936, 27937), (29254, 29255), (4326, 4327)}
# Validation Loss: 0.05433747897623107
# Validation Accuracy: 0.9274474193457393
# Chunk Precision: 0.5305164319248826
# Chunk Recall: 0.09047237790232186
# Chunk F1: 0.1545827633378933
#               precision    recall  f1-score   support
#
#            _       0.52      0.09      0.16      1249
#
#    micro avg       0.52      0.09      0.16      1249
#    macro avg       0.52      0.09      0.16      1249
# weighted avg       0.52      0.09      0.16      1249
#
# Training epoch: 2
# Training loss per 100 training steps: 0.09427209943532944
# Training loss per 100 training steps: 0.061786498855983855
# Training loss epoch: 0.05651690432445166
# Training accuracy epoch: 0.9175472055487427
# Validation loss per 100 evaluation steps: 0.023113630712032318
# Validation loss per 100 evaluation steps: 0.04495290042166852
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (27992, 27993), (16866, 16867), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (8219, 8220), (18377, 18378), (18487, 18488), (16867, 16868), (8688, 8689), (16128, 16129), (4970, 4971), (4608, 4609), (26286, 26287), (23826, 23827), (14600, 14601), (16069, 16070), (25639, 25640), (27230, 27233), (12760, 12761), (16900, 16901), (28090, 28091), (4305, 4306), (13591, 13592), (9914, 9915), (21408, 21409), (4264, 4265), (8813, 8814), (27999, 28000), (19443, 19444), (28981, 28982), (4035, 4036), (468, 469), (16102, 16103), (21500, 21501), (17084, 17085), (14120, 14121), (22482, 22483), (25640, 25641), (28091, 28092), (21441, 21442), (8814, 8815), (3054, 3055), (258, 259), (18384, 18385), (4036, 4037), (16874, 16875), (25613, 25614), (28426, 28427), (8167, 8168), (5959, 5960), (27973, 27974), (5220, 5221), (2256, 2257), (8410, 8411), (18845, 18847), (9980, 9981), (259, 260), (4220, 4221), (13717, 13718), (18376, 18377), (5749, 5750), (14580, 14581), (2063, 2064), (28098, 28099), (5194, 5195), (29291, 29292), (13222, 13223), (5993, 5994), (7705, 7706), (25680, 25681), (28980, 28981), (4286, 4287), (5195, 5196), (26621, 26622), (17216, 17217), (16083, 16084), (4227, 4228), (8477, 8478), (1827, 1828), (5967, 5968), (6150, 6151), (11759, 11760), (12347, 12348), (17157, 17158), (21407, 21408), (17217, 17218), (29316, 29317), (26048, 26049), (14496, 14497), (2599, 2600), (26728, 26729), (21330, 21331), (3053, 3054), (13472, 13473), (21289, 21290), (8300, 8301), (26898, 26899), (6863, 6864), (26292, 26293), (5973, 5974), (2255, 2256), (19491, 19492), (14125, 14126), (18601, 18602), (21304, 21305), (29231, 29232), (19206, 19207), (18844, 18845), (4386, 4387), (27703, 27704), (14126, 14127), (28097, 28098), (14158, 14159), (27207, 27208), (3060, 3061), (12346, 12347), (26905, 26906), (4378, 4379), (18937, 18938), (28297, 28299), (19919, 19920), (14159, 14160), (19180, 19181), (11951, 11952), (25771, 25772), (4319, 4320), (16082, 16083), (21329, 21330), (4562, 4563), (8114, 8115), (26938, 26939), (4411, 4412), (6132, 6133), (27149, 27150), (27920, 27921), (29279, 29280), (24973, 24974), (27980, 27981), (26879, 26880), (5847, 5848), (25653, 25654), (4563, 4564), (1657, 1658), (7055, 7056), (14495, 14496), (18383, 18384), (21724, 21725), (5577, 5578), (26273, 26274), (9355, 9356), (27953, 27954), (12866, 12867), (3916, 3917), (8827, 8828), (21303, 21304), (8676, 8677), (26912, 26913), (120, 121), (21395, 21396), (24947, 24948), (27954, 27955), (7635, 7636), (25778, 25779), (61, 62), (3839, 3840), (26325, 26326), (27927, 27928), (18600, 18601), (25779, 25780), (6291, 6292), (8170, 8172), (25871, 25872), (3, 4), (26340, 26341), (5644, 5645), (25812, 25813), (2514, 2515), (5704, 5705), (16123, 16124), (25693, 25694), (4226, 4227), (4075, 4076), (27222, 27223), (21462, 21463), (25634, 25635), (21554, 21555), (28296, 28297), (25575, 25576), (20875, 20876), (3621, 3622), (17079, 17080), (19498, 19499), (21377, 21379), (22569, 22570), (25759, 25760), (8221, 8222), (14601, 14602), (18851, 18852), (14812, 14813), (8281, 8282), (26911, 26912), (21739, 21740), (8011, 8012), (9842, 9843), (15451, 15452), (25760, 25761), (27229, 27230), (14602, 14603), (26742, 26743), (19261, 19262), (8465, 8466), (2117, 2118), (26339, 26340), (16163, 16164), (26793, 26794), (8195, 8196), (16617, 16618), (15484, 15485), (4326, 4327), (16104, 16105), (26885, 26886), (1756, 1757), (8498, 8499), (17784, 17785), (28093, 28094), (4418, 4419), (13594, 13595), (29245, 29246), (24467, 24468), (26188, 26189), (3620, 3621), (8169, 8170), (4240, 4241), (29278, 29279), (261, 262), (24468, 24469), (18891, 18892), (13719, 13720), (16138, 16139), (27690, 27691), (26180, 26181), (12603, 12604), (11953, 11955), (13223, 13224), (24592, 24593), (2065, 2066), (7674, 7675), (9354, 9355), (14265, 14266), (18892, 18893), (26741, 26742), (21343, 21344), (27691, 27692), (29311, 29312), (16171, 16172), (5196, 5197), (25851, 25852), (26833, 26834), (29252, 29253), (21284, ...
# Validation Loss: 0.04043347694261339
# Validation Accuracy: 0.9371959559977826
# Chunk Precision: 0.42069741282339707
# Chunk Recall: 0.29943955164131303
# Chunk F1: 0.34985968194574363
#               precision    recall  f1-score   support
#
#            _       0.42      0.30      0.35      1249
#
#    micro avg       0.42      0.30      0.35      1249
#    macro avg       0.42      0.30      0.35      1249
# weighted avg       0.42      0.30      0.35      1249
#
# Training epoch: 3
# Training loss per 100 training steps: 0.06066874414682388
# Training loss per 100 training steps: 0.044570827026768484
# Training loss epoch: 0.042800420454326776
# Training accuracy epoch: 0.931907560726816
# Validation loss per 100 evaluation steps: 0.017879096791148186
# Validation loss per 100 evaluation steps: 0.04237938981236991
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (19074, 19075), (28612, 28613), (16866, 16867), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (12347, 12349), (8466, 8469), (18487, 18488), (16867, 16868), (21526, 21527), (16128, 16129), (3910, 3911), (4970, 4971), (26286, 26287), (5590, 5591), (23826, 23827), (27998, 27999), (8451, 8453), (14600, 14601), (16069, 16070), (25019, 25020), (5682, 5683), (24506, 24507), (25639, 25640), (4172, 4173), (12760, 12761), (16900, 16901), (25850, 25851), (27230, 27233), (28090, 28091), (4305, 4306), (5591, 5592), (8193, 8194), (4264, 4265), (20921, 20922), (27999, 28000), (19443, 19444), (3264, 3265), (468, 469), (4035, 4036), (16102, 16103), (17084, 17085), (14120, 14121), (21500, 21501), (22482, 22483), (25640, 25641), (28091, 28092), (21304, 21306), (8194, 8195), (28922, 28923), (21441, 21442), (3054, 3055), (258, 259), (18384, 18385), (4036, 4037), (16874, 16875), (25613, 25614), (26806, 26807), (28426, 28427), (14698, 14699), (8167, 8168), (5959, 5960), (27973, 27974), (5220, 5221), (2256, 2257), (23195, 23196), (9980, 9981), (259, 260), (4220, 4221), (13717, 13718), (5749, 5750), (24967, 24968), (18919, 18921), (14580, 14581), (2063, 2064), (3061, 3063), (19661, 19662), (18922, 18923), (28098, 28099), (19920, 19922), (5194, 5195), (29291, 29292), (13222, 13223), (5993, 5994), (4153, 4154), (25831, 25832), (114, 115), (14495, 14497), (17092, 17093), (25680, 25681), (4286, 4287), (9355, 9357), (5195, 5196), (26621, 26622), (8417, 8418), (17216, 17217), (16083, 16084), (4227, 4228), (8477, 8478), (24505, 24506), (17276, 17277), (147, 148), (1827, 1828), (5967, 5968), (6150, 6151), (11759, 11760), (17157, 17158), (21297, 21298), (17217, 17218), (28618, 28619), (8299, 8300), (29316, 29317), (21437, 21439), (26048, 26049), (26746, 26747), (2599, 2600), (26728, 26729), (21330, 21331), (3053, 3054), (13472, 13473), (26898, 26899), (483, 484), (8300, 8301), (6863, 6864), (21969, 21970), (5973, 5974), (26292, 26293), (2255, 2256), (14125, 14126), (24361, 24362), (3917, 3918), (18601, 18602), (29231, 29232), (21462, 21464), (4386, 4387), (27703, 27704), (14126, 14127), (28097, 28098), (14158, 14159), (27207, 27208), (27795, 27796), (3060, 3061), (12346, 12347), (26905, 26906), (4378, 4379), (18937, 18938), (28297, 28299), (19919, 19920), (14159, 14160), (19180, 19181), (11951, 11952), (25771, 25772), (4319, 4320), (16082, 16083), (21329, 21330), (4562, 4563), (8114, 8115), (21540, 21541), (26938, 26939), (146, 147), (4411, 4412), (6132, 6133), (27149, 27150), (16400, 16401), (19952, 19953), (24973, 24974), (14602, 14604), (27980, 27981), (29279, 29280), (26181, 26182), (26879, 26880), (5847, 5848), (25653, 25654), (7055, 7056), (4563, 4564), (1657, 1658), (4957, 4958), (18383, 18384), (26273, 26274), (5577, 5578), (27953, 27954), (12866, 12867), (3916, 3917), (8827, 8828), (21303, 21304), (26912, 26913), (2328, 2329), (3278, 3279), (120, 121), (22496, 22497), (16736, 16737), (21395, 21396), (5578, 5579), (24947, 24948), (27954, 27955), (25778, 25779), (61, 62), (3839, 3840), (26325, 26326), (23057, 23058), (27927, 27928), (15998, 15999), (18600, 18601), (25779, 25780), (5854, 5855), (2513, 2514), (6291, 6292), (25871, 25872), (26340, 26341), (12601, 12604), (5644, 5645), (2303, 2304), (25812, 25813), (2697, 2698), (2514, 2515), (5704, 5705), (16123, 16124), (25693, 25694), (4226, 4227), (7054, 7055), (4075, 4076), (25634, 25635), (4167, 4168), (21554, 21555), (28296, 28297), (8808, 8809), (2671, 2672), (3621, 3622), (6811, 6812), (4241, 4242), (17079, 17080), (8129, 8130), (19498, 19499), (22569, 22570), (25759, 25760), (19590, 19591), (28000, 28002), (4182, 4183), (14601, 14602), (14812, 14813), (8281, 8282), (14073, 14074), (19471, 19472), (16130, 16131), (26911, 26912), (21739, 21740), (1043, 1044), (15451, 15452), (25760, 25761), (27229, 27230), (25021, 25022), (26742, 26743), (19261, 19262), (8465, 8466), (2117, 2118), (18884, 18885), (26339, 26340), (24342, 24343), (16163, 16164), (26793, ...
# Validation Loss: 0.0369583502627368
# Validation Accuracy: 0.947322146900434
# Chunk Precision: 0.4390909090909091
# Chunk Recall: 0.3867093674939952
# Chunk F1: 0.4112388250319285
#               precision    recall  f1-score   support
#
#            _       0.43      0.39      0.41      1249
#
#    micro avg       0.43      0.39      0.41      1249
#    macro avg       0.43      0.39      0.41      1249
# weighted avg       0.43      0.39      0.41      1249
#
# Training epoch: 4
# Training loss per 100 training steps: 0.017713528126478195
# Training loss per 100 training steps: 0.03687397823991752
# Training loss epoch: 0.03537358759228695
# Training accuracy epoch: 0.9440762452660009
# Validation loss per 100 evaluation steps: 0.015720229595899582
# Validation loss per 100 evaluation steps: 0.0407079440494884
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (27992, 27993), (19074, 19075), (28612, 28613), (16866, 16867), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (16867, 16868), (21526, 21527), (16128, 16129), (4970, 4971), (26286, 26287), (5590, 5591), (23826, 23827), (19499, 19501), (27998, 27999), (8451, 8453), (5833, 5834), (16069, 16070), (25019, 25020), (25639, 25640), (24506, 24507), (27230, 27233), (12760, 12761), (16312, 16313), (25850, 25851), (5925, 5926), (4305, 4306), (5591, 5592), (8193, 8194), (4264, 4265), (27999, 28000), (2676, 2677), (3264, 3265), (4035, 4036), (16102, 16103), (21500, 21501), (17084, 17085), (22482, 22483), (25640, 25641), (21304, 21306), (8194, 8195), (6757, 6758), (21441, 21442), (3054, 3055), (18384, 18385), (25613, 25614), (28426, 28427), (5217, 5219), (16874, 16875), (19476, 19477), (20884, 20887), (26806, 26807), (14698, 14699), (27703, 27705), (8167, 8168), (26614, 26615), (27973, 27974), (5220, 5221), (2256, 2257), (12347, 12353), (17786, 17789), (23195, 23196), (9980, 9981), (4220, 4221), (13717, 13718), (5749, 5750), (24967, 24968), (18919, 18921), (14580, 14581), (2063, 2064), (8281, 8284), (5690, 5691), (18922, 18923), (27149, 27151), (19920, 19922), (8673, 8677), (21929, 21930), (29291, 29292), (13222, 13223), (4153, 4154), (25831, 25832), (114, 115), (17092, 17093), (25680, 25681), (4286, 4287), (20330, 20332), (23472, 23473), (9355, 9357), (26621, 26622), (8417, 8418), (17216, 17217), (4227, 4228), (8477, 8478), (24505, 24506), (17276, 17277), (147, 148), (6150, 6151), (5967, 5968), (11759, 11760), (17157, 17158), (5228, 5229), (21297, 21298), (17217, 17218), (3640, 3641), (14647, 14648), (8299, 8300), (28618, 28619), (26048, 26049), (26746, 26747), (29316, 29317), (4471, 4472), (2599, 2600), (5201, 5202), (26728, 26729), (21330, 21331), (3053, 3054), (13472, 13473), (23010, 23011), (483, 484), (8300, 8301), (6863, 6864), (25461, 25462), (26898, 26899), (8303, 8306), (5973, 5974), (21969, 21970), (26292, 26293), (2255, 2256), (14125, 14126), (24361, 24362), (3917, 3918), (18601, 18602), (29231, 29232), (15167, 15168), (4386, 4387), (15503, 15504), (4268, 4270), (14126, 14127), (14369, 14370), (8466, 8472), (12346, 12347), (26905, 26906), (18937, 18938), (19919, 19920), (19180, 19181), (11951, 11952), (4182, 4184), (25771, 25772), (4319, 4320), (21329, 21330), (4562, 4563), (8114, 8115), (21540, 21541), (26938, 26939), (146, 147), (4411, 4412), (6132, 6133), (28090, 28094), (13620, 13622), (16400, 16401), (19952, 19953), (27980, 27981), (28939, 28943), (19261, 19263), (26181, 26182), (26879, 26880), (5847, 5848), (25653, 25654), (4563, 4564), (1657, 1658), (4957, 4958), (7055, 7056), (14872, 14873), (18383, 18384), (23493, 23495), (24342, 24344), (26273, 26274), (27953, 27954), (12866, 12867), (3916, 3917), (16644, 16645), (21303, 21304), (26912, 26913), (3278, 3279), (120, 121), (22496, 22497), (21395, 21396), (27954, 27955), (25778, 25779), (61, 62), (3839, 3840), (26325, 26326), (2329, 2330), (23057, 23058), (27927, 27928), (15998, 15999), (18600, 18601), (19808, 19809), (8809, 8815), (25779, 25780), (2664, 2665), (5854, 5855), (16090, 16091), (27690, 27691), (2513, 2514), (6291, 6292), (25871, 25872), (26340, 26341), (12601, 12604), (5644, 5645), (4223, 4225), (2303, 2304), (19464, 19465), (2697, 2698), (2514, 2515), (5704, 5705), (16123, 16124), (16171, 16173), (25693, 25694), (25812, 25813), (4226, 4227), (27982, 27985), (7054, 7055), (4075, 4076), (25634, 25635), (4167, 4168), (21554, 21555), (18575, 18576), (8808, 8809), (2671, 2672), (3621, 3622), (6811, 6812), (25457, 25459), (17079, 17080), (8129, 8130), (19498, 19499), (22569, 22570), (13619, 13620), (14679, 14680), (19050, 19052), (19590, 19591), (23478, 23479), (25759, 25760), (14812, 14813), (28000, 28002), (19471, 19472), (14073, 14074), (26911, 26912), (5711, 5712), (19682, 19683), (21739, 21740), (28270, 28271), (28119, 28120), (1043, 1044), (15451, 15452), (25760, 25761), (21831, 21832), (25021, 2 ...
# Validation Loss: 0.03561031656273691
# Validation Accuracy: 0.9489133211742707
# Chunk Precision: 0.4832618025751073
# Chunk Recall: 0.45076060848678945
# Chunk F1: 0.4664457332228666
#               precision    recall  f1-score   support
#
#            _       0.47      0.45      0.46      1249
#
#    micro avg       0.47      0.45      0.46      1249
#    macro avg       0.47      0.45      0.46      1249
# weighted avg       0.47      0.45      0.46      1249
#
# Training epoch: 5
# Training loss per 100 training steps: 0.040616415441036224
# Training loss per 100 training steps: 0.030296934980640906
# Training loss epoch: 0.030348903838881947
# Training accuracy epoch: 0.9508631000143336
# Validation loss per 100 evaluation steps: 0.019943272694945335
# Validation loss per 100 evaluation steps: 0.04343071260529433
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (27992, 27993), (19074, 19075), (28612, 28613), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (23398, 23399), (21526, 21527), (3910, 3911), (4970, 4971), (26286, 26287), (23826, 23827), (19499, 19501), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (25019, 25020), (25639, 25640), (24506, 24507), (27230, 27233), (12760, 12761), (25850, 25851), (5925, 5926), (4305, 4306), (21408, 21409), (4264, 4265), (27999, 28000), (2676, 2677), (3264, 3265), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (21304, 21306), (3054, 3055), (18384, 18385), (25613, 25614), (28426, 28427), (19476, 19477), (27703, 27705), (26806, 26807), (8167, 8168), (5959, 5960), (26614, 26615), (27973, 27974), (5220, 5221), (2256, 2257), (12347, 12353), (17786, 17789), (23195, 23196), (9980, 9981), (4220, 4221), (13749, 13750), (5749, 5750), (399, 401), (18919, 18921), (14580, 14581), (2063, 2064), (3061, 3063), (19661, 19662), (18922, 18923), (19920, 19922), (8673, 8677), (29291, 29292), (13222, 13223), (5575, 5579), (4153, 4154), (25831, 25832), (114, 115), (14495, 14497), (17092, 17093), (25680, 25681), (4286, 4287), (23472, 23473), (26621, 26622), (8417, 8418), (16083, 16084), (4227, 4228), (24505, 24506), (147, 148), (5967, 5968), (11759, 11760), (17157, 17158), (21297, 21298), (21407, 21408), (28618, 28619), (8299, 8300), (29316, 29317), (26048, 26049), (26746, 26747), (2599, 2600), (5201, 5202), (26728, 26729), (21330, 21331), (3840, 3842), (3053, 3054), (13472, 13473), (23010, 23011), (483, 484), (8300, 8301), (6863, 6864), (26898, 26899), (21969, 21970), (5973, 5974), (26292, 26293), (2255, 2256), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (14126, 14127), (14369, 14370), (27207, 27208), (3909, 3910), (3060, 3061), (8466, 8472), (12346, 12347), (26905, 26906), (4378, 4379), (18937, 18938), (28297, 28299), (19919, 19920), (11951, 11952), (4182, 4184), (25771, 25772), (4319, 4320), (16082, 16083), (21329, 21330), (4562, 4563), (8114, 8115), (21540, 21541), (26938, 26939), (146, 147), (4411, 4412), (6132, 6133), (29279, 29280), (16400, 16401), (19952, 19953), (14602, 14604), (27980, 27981), (26181, 26182), (26879, 26880), (5847, 5848), (25653, 25654), (4563, 4564), (1657, 1658), (4957, 4958), (7055, 7056), (18383, 18384), (27953, 27954), (9355, 9356), (15484, 15486), (12866, 12867), (21303, 21304), (14074, 14075), (26912, 26913), (120, 121), (11127, 11128), (15466, 15468), (21395, 21396), (27954, 27955), (5427, 5428), (25778, 25779), (61, 62), (3839, 3840), (26325, 26326), (17087, 17089), (23057, 23058), (8169, 8171), (27927, 27928), (18600, 18601), (19808, 19809), (8809, 8815), (25779, 25780), (2664, 2665), (5854, 5855), (6291, 6292), (25871, 25872), (26340, 26341), (12601, 12604), (5644, 5645), (2303, 2304), (25812, 25813), (2697, 2698), (23352, 23353), (5704, 5705), (16171, 16173), (25693, 25694), (4226, 4227), (27982, 27985), (7054, 7055), (4075, 4076), (8438, 8444), (25634, 25635), (21554, 21555), (28296, 28297), (18575, 18576), (8808, 8809), (2671, 2672), (3621, 3622), (6811, 6812), (17079, 17080), (19498, 19499), (14679, 14680), (19590, 19591), (25759, 25760), (14601, 14602), (28000, 28002), (14812, 14813), (8281, 8282), (14073, 14074), (19471, 19472), (26911, 26912), (28270, 28271), (21739, 21740), (28119, 28120), (15451, 15452), (25760, 25761), (27229, 27230), (25021, 25022), (26742, 26743), (19261, 19262), (8465, 8466), (12674, 12678), (18884, 18885), (25852, 25853), (26339, 26340), (24342, 24343), (26793, 26794), (22754, 22755), (5216, 5217), (49, 51), (16617, 16618), (4326, 4327), (16104, 16105), (26885, 26886), (1756, 1757), (17784, 17785), (13745, 13746), (16347, 16348), (12629, 12630), (28097, 28101), (4267, 4268), (16817, 16819), (29245, 29246), (26188, 26189), (2711, 2712), (13309, 13310), (18918, 18919), (3620, 3621), (16348, 16349), (4240, 4241), (6131, 6132), (14609, 14610), (83, 85), (261, 262), (1889 ...
# Validation Loss: 0.03667650336092511
# Validation Accuracy: 0.9517358486838631
# Chunk Precision: 0.532608695652174
# Chunk Recall: 0.4315452361889512
# Chunk F1: 0.47678018575851394
#               precision    recall  f1-score   support
#
#            _       0.52      0.43      0.47      1249
#
#    micro avg       0.52      0.43      0.47      1249
#    macro avg       0.52      0.43      0.47      1249
# weighted avg       0.52      0.43      0.47      1249
#
# Training epoch: 6
# Training loss per 100 training steps: 0.019561145454645157
# Training loss per 100 training steps: 0.0274327116059416
# Training loss epoch: 0.02641169305524214
# Training accuracy epoch: 0.9593147405306708
# Validation loss per 100 evaluation steps: 0.012287798337638378
# Validation loss per 100 evaluation steps: 0.04223568107347704
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# ...
# {(2064, 2065), (27992, 27993), (19074, 19075), (21493, 21494), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (25757, 25758), (16368, 16370), (4970, 4971), (16748, 16749), (23490, 23491), (26286, 26287), (5590, 5591), (23826, 23827), (19499, 19501), (25758, 25759), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (19048, 19049), (25019, 25020), (25639, 25640), (23431, 23432), (12760, 12761), (22298, 22299), (25850, 25851), (4305, 4306), (20532, 20534), (5591, 5592), (21408, 21409), (4264, 4265), (26319, 26320), (27999, 28000), (8484, 8486), (3264, 3265), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (2107, 2111), (14120, 14121), (24162, 24163), (21304, 21306), (13624, 13625), (21441, 21442), (14156, 14160), (14622, 14624), (3054, 3055), (13473, 13474), (18384, 18385), (24103, 24104), (25613, 25614), (27703, 27705), (21533, 21534), (20884, 20887), (28426, 28427), (8167, 8168), (24085, 24086), (27973, 27974), (5220, 5221), (2256, 2257), (8410, 8411), (12188, 12189), (12347, 12353), (13625, 13626), (23195, 23196), (4220, 4221), (8278, 8282), (13749, 13750), (16168, 16169), (12129, 12130), (399, 401), (14580, 14581), (8411, 8412), (2063, 2064), (18922, 18923), (19920, 19922), (8673, 8677), (6553, 6554), (27208, 27209), (13222, 13223), (16412, 16413), (11785, 11786), (26831, 26832), (7222, 7225), (25831, 25832), (8293, 8294), (114, 115), (14872, 14874), (17092, 17093), (25680, 25681), (23472, 23473), (20330, 20332), (4833, 4834), (8417, 8418), (11818, 11819), (4227, 4228), (8477, 8478), (24143, 24144), (7635, 7637), (17157, 17158), (5605, 5606), (21297, 21298), (5228, 5229), (21407, 21408), (26805, 26806), (27636, 27637), (12926, 12927), (8299, 8300), (14647, 14648), (21437, 21439), (4958, 4959), (16737, 16739), (26048, 26049), (2599, 2600), (5201, 5202), (26728, 26729), (21330, 21331), (16179, 16182), (21440, 21441), (3840, 3842), (3053, 3054), (13472, 13473), (26898, 26899), (483, 484), (8300, 8301), (6863, 6864), (25461, 25462), (16360, 16361), (21969, 21970), (26292, 26293), (2255, 2256), (13850, 13851), (5294, 5295), (27702, 27703), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (13355, 13356), (28097, 28098), (6369, 6370), (27207, 27208), (28777, 28778), (8466, 8472), (12346, 12347), (4378, 4379), (28297, 28299), (19919, 19920), (11951, 11952), (4832, 4833), (20787, 20791), (21448, 21449), (22807, 22808), (28607, 28613), (21329, 21330), (8114, 8115), (26938, 26939), (4411, 4412), (6132, 6133), (29279, 29280), (28090, 28094), (13620, 13622), (16400, 16401), (27980, 27981), (19801, 19802), (26181, 26182), (26879, 26880), (5847, 5848), (6435, 6436), (25653, 25654), (7055, 7056), (1657, 1658), (4957, 4958), (26273, 26274), (18383, 18384), (28120, 28122), (5577, 5578), (27953, 27954), (12866, 12867), (3916, 3917), (28784, 28785), (21303, 21304), (14074, 14075), (26912, 26913), (11866, 11867), (6468, 6469), (120, 121), (11127, 11128), (16736, 16737), (21395, 21396), (5578, 5579), (27954, 27955), (4839, 4840), (5427, 5428), (6560, 6561), (12867, 12868), (25778, 25779), (61, 62), (8431, 8437), (3839, 3840), (11656, 11657), (17087, 17089), (13698, 13699), (26325, 26326), (27927, 27928), (18600, 18601), (24980, 24981), (13822, 13823), (8809, 8815), (19808, 19809), (25779, 25780), (5854, 5855), (16090, 16091), (6291, 6292), (25871, 25872), (26340, 26341), (5644, 5645), (2303, 2304), (13310, 13311), (2697, 2698), (23352, 23353), (25812, 25813), (16171, 16173), (25693, 25694), (4226, 4227), (24183, 24184), (7054, 7055), (27982, 27985), (4075, 4076), (27222, 27223), (21462, 21463), (8438, 8444), (25634, 25635), (21554, 21555), (28296, 28297), (18575, 18576), (8808, 8809), (2671, 2672), (3621, 3622), (25457, 25459), (4241, 4242), (17079, 17080), (19498, 19499), (13619, 13620), (25759, 25760), (19050, 19052), (4182, 4183), (14601, 14602), (28000, 28002), (14812, 14813), (14073, 14074), (26911, 26912), (16130, 16131), (1968 ...
# Validation Loss: 0.0962572483261287
# Validation Accuracy: 0.9554829520458614
# Chunk Precision: 0.5827645051194539
# Chunk Recall: 0.5468374699759808
# Chunk F1: 0.5642296571664601
#               precision    recall  f1-score   support
#
#            _       0.58      0.55      0.56      1249
#
#    micro avg       0.58      0.55      0.56      1249
#    macro avg       0.58      0.55      0.56      1249
# weighted avg       0.58      0.55      0.56      1249
#
# Training epoch: 50
# Training loss per 100 training steps: 0.0005201916210353374
# Training loss per 100 training steps: 0.0006303324528143193
# Training loss epoch: 0.0005644729816663855
# Training accuracy epoch: 0.999162090886074
# Validation loss per 100 evaluation steps: 0.014405729249119759
# Validation loss per 100 evaluation steps: 0.11982853178824428
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (27992, 27993), (19074, 19075), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (25757, 25758), (16368, 16370), (4970, 4971), (16748, 16749), (23490, 23491), (23826, 23827), (19499, 19501), (25758, 25759), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (14648, 14650), (19048, 19049), (25019, 25020), (25639, 25640), (23431, 23432), (12760, 12761), (22298, 22299), (25850, 25851), (20532, 20534), (21408, 21409), (26319, 26320), (4264, 4265), (27999, 28000), (3264, 3265), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (2107, 2111), (24162, 24163), (21304, 21306), (16194, 16195), (13624, 13625), (21441, 21442), (14156, 14160), (14622, 14624), (3054, 3055), (13473, 13474), (18384, 18385), (24103, 24104), (25613, 25614), (27703, 27705), (26806, 26807), (20884, 20887), (28426, 28427), (8167, 8168), (27973, 27974), (5220, 5221), (2256, 2257), (8410, 8411), (12188, 12189), (12347, 12353), (13625, 13626), (23195, 23196), (4220, 4221), (13749, 13750), (16168, 16169), (12129, 12130), (399, 401), (26798, 26799), (8411, 8412), (2063, 2064), (18922, 18923), (19920, 19922), (8673, 8677), (6553, 6554), (27208, 27209), (13222, 13223), (16412, 16413), (11785, 11786), (26831, 26832), (7705, 7706), (14872, 14874), (114, 115), (25831, 25832), (17092, 17093), (25680, 25681), (23472, 23473), (4833, 4834), (8417, 8418), (11818, 11819), (14074, 14076), (4227, 4228), (24143, 24144), (17157, 17158), (21297, 21298), (8617, 8619), (5228, 5229), (21407, 21408), (26805, 26806), (12926, 12927), (8299, 8300), (14647, 14648), (21437, 21439), (4958, 4959), (16737, 16739), (26048, 26049), (2599, 2600), (16208, 16209), (26728, 26729), (21330, 21331), (16179, 16182), (21440, 21441), (3840, 3842), (3053, 3054), (13472, 13473), (26898, 26899), (483, 484), (8300, 8301), (6863, 6864), (25461, 25462), (16360, 16361), (21969, 21970), (26292, 26293), (2255, 2256), (13850, 13851), (5294, 5295), (8484, 8485), (27702, 27703), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (13355, 13356), (28097, 28098), (14369, 14370), (6369, 6370), (27207, 27208), (8466, 8472), (12346, 12347), (28297, 28299), (19919, 19920), (11951, 11952), (4832, 4833), (4182, 4184), (14370, 14371), (21448, 21449), (22807, 22808), (28607, 28613), (21329, 21330), (8114, 8115), (24519, 24520), (26938, 26939), (4411, 4412), (6132, 6133), (29279, 29280), (28090, 28094), (13620, 13622), (16400, 16401), (27980, 27981), (19801, 19802), (26181, 26182), (26879, 26880), (5847, 5848), (6435, 6436), (25653, 25654), (26310, 26314), (1657, 1658), (4957, 4958), (22722, 22724), (18383, 18384), (23493, 23495), (5577, 5578), (27953, 27954), (28120, 28122), (12866, 12867), (3916, 3917), (16644, 16645), (28784, 28785), (21303, 21304), (88, 89), (11866, 11867), (6468, 6469), (120, 121), (11127, 11128), (26912, 26913), (16736, 16737), (21395, 21396), (5578, 5579), (27954, 27955), (7635, 7636), (4839, 4840), (5427, 5428), (12867, 12868), (25778, 25779), (61, 62), (8431, 8437), (3839, 3840), (11656, 11657), (17087, 17089), (13698, 13699), (18885, 18886), (27927, 27928), (18600, 18601), (24980, 24981), (13822, 13823), (8809, 8815), (19808, 19809), (25779, 25780), (5854, 5855), (16090, 16091), (6291, 6292), (25871, 25872), (26340, 26341), (5644, 5645), (2303, 2304), (13310, 13311), (2697, 2698), (23352, 23353), (25812, 25813), (16171, 16173), (25693, 25694), (4226, 4227), (24183, 24184), (27982, 27985), (21462, 21463), (8438, 8444), (25634, 25635), (21554, 21555), (28296, 28297), (18575, 18576), (8808, 8809), (3621, 3622), (25457, 25459), (4241, 4242), (17079, 17080), (19498, 19499), (13619, 13620), (25759, 25760), (19050, 19052), (14601, 14602), (23478, 23479), (28000, 28002), (14812, 14813), (14073, 14074), (26911, 26912), (28270, 28271), (21739, 21740), (28119, 28120), (19169, 19170), (19774, 19775), (25760, 25761), (27229, 27230), (14602, 14603), (26742, 26743), (8465, 8466), (12674, 12678), (18 ...
# Validation Loss: 0.09757272322335189
# Validation Accuracy: 0.9545862063718938
# Chunk Precision: 0.5794392523364486
# Chunk Recall: 0.49639711769415534
# Chunk F1: 0.5347132384648555
#               precision    recall  f1-score   support
#
#            _       0.57      0.50      0.53      1249
#
#    micro avg       0.57      0.50      0.53      1249
#    macro avg       0.57      0.50      0.53      1249
# weighted avg       0.57      0.50      0.53      1249

# %% [markdown]
# **evaluating the model before self-training:**

# %%
import copy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#model.to(device)
_, labels, predictions = valid(model, testing_loader)
print(labels[:30], predictions[:30])
print(classification_report([labels], [predictions]))
conf=confusion_matrix(labels, predictions, labels=["B", "I", "O"])
disp = ConfusionMatrixDisplay(confusion_matrix=conf, display_labels=["B", "I", "O"])
disp.plot()
plt.show()

def get_predictions(model, loader, model_name=""):
  dataset = copy.deepcopy(loader.dataset)
  dataset.set_model(model, model_name)
  return dataset


def eval_dummy():
  dummy = DummyClassifier(strategy='most_frequent')
  train_real_dataset = {"words": [], "labels": []}
  test_real_dataset = {"words": [], "labels": []}
  for (sentence, labels) in zip(train_dataset["sentence"], train_dataset["word_labels"]):
      train_real_dataset["words"].extend(sentence)
      train_real_dataset["labels"].extend(labels)
  for (sentence, labels) in zip(test_dataset["sentence"], test_dataset["word_labels"]):
      test_real_dataset["words"].extend(sentence)
      test_real_dataset["labels"].extend(labels)
  dummy.fit(train_real_dataset["words"], train_real_dataset["labels"])

  _predictions = dummy.predict(test_real_dataset["words"])
  print("Dummy Accuracy:", dummy.score(_predictions.tolist(), test_real_dataset["labels"]))
  print(classification_report([test_real_dataset["labels"]], [_predictions.tolist()]))

def extract_concepts(dataset, gold=False):
  concepts=set()
  concept=[]
  extracting = False
  field = 'targets' if gold else 'predictions'
  for processed in dataset:
    for i in range(len(processed['ids'])):
      if id2label[processed[field][i].item()] == "O" and extracting:
        concepts.add(tokenizer.decode(concept))
        concept = []
        extracting = False
      if id2label[processed[field][i].item()] == "B":
        if extracting and not tokenizer.convert_ids_to_tokens(processed['ids'][i].item()).startswith("##"):
          concepts.add(tokenizer.decode(concept))
          concept = []
        extracting = True
      if extracting:
        concept.append(processed['ids'][i].item())
  return concepts

def eval_deck(concepts, gold_concepts):
	fn = gold_concepts - concepts
	tp = gold_concepts & concepts
	fp = concepts - gold_concepts
	print(f"TP: {len(tp)}, FP: {len(fp)}, FN: {len(fn)}")
	return (len(tp),len(fp),len(fn))

def eval_concepts(model, deck_loader_list):
  tp, fp, fn = 0, 0, 0
  for deck_loader in deck_loader_list:
    pred_ds = get_predictions(model, deck_loader)
    concepts = extract_concepts(pred_ds)
    gold_concepts = extract_concepts(pred_ds, gold=True)
    tp_c, fp_c, fn_c = eval_deck(concepts, gold_concepts)
    tp += tp_c
    fp += fp_c
    fn += fn_c
  p = tp / (tp + fp) if tp + fp > 0 else 0
  r = tp / (tp + fn) if tp + fn > 0 else 0
  f1 = 2 * (p * r) / (p + r) if p + r > 0 else 0
  print(f"precision: {p}, recall: {r}, F1: {f1}")

eval_concepts(model, test_block_loader)
model.push_to_hub("AwesomeREK/concept-extraction-xlnet")

#model.save_pretrained("./xlnet-concept-extractor-model-distant-half-labels/model/")
#tokenizer.save_pretrained("./xlnet-concept-extractor-model-distant-half-labels/tokenizer/")
#!zip -r xlnet-concept-extractor-model-distant-half-labels.zip xlnet-concept-extractor-model-distant-half-labels
# Out:
# Validation loss per 100 evaluation steps: 0.014405729249119759
# Validation loss per 100 evaluation steps: 0.11982853178824428

# %% [markdown]
# # New Kind of Self-Training:
#
# 1. Divide unlabeled data into two seperate sets of courses.
#
# 2. One model outputs predictions on one set of courses, the other the other set.
#
# 3. The first model learns based off of the second model's prediction for N epochs, and vice versa.
#
# 4. Then they swap sets, now being "experts", and output their predictions on those sets.
#
# 5. They train off of these predictions for N epochs
#
# 6. Repeat for K times, or until they do not do better on the validation set
#
# 7. Finally, pick the one with the lowest validation loss on the validation set

# %% [markdown]
# **self-training:**

# %%
#del model_1
#del model_2
#del model_best
torch.cuda.empty_cache()
model_1 = copy.deepcopy(model)
model_2 = copy.deepcopy(model)
model_best = copy.deepcopy(model)
model_1.to(device)
model_2.to(device)
model_best.to(device)
optimizer_1 = torch.optim.Adam(params=model_1.parameters(), lr=LEARNING_RATE)
optimizer_2 = torch.optim.Adam(params=model_2.parameters(), lr=LEARNING_RATE)



best_model_init = False
ROUNDS = 4
SELF_TRAIN_EPOCH = 5
self_training_type = "ts"

def p2p_self_train(model_1, model_2, model_best, optimizer_1, optimizer_2, self_training_loader_1, self_training_loader_2, validation_loader, rounds, self_epochs, best_model_init=False):
  predicted_training_loader_1 = DataLoader(get_predictions(model_1, self_training_loader_1, model_name="model_1"), **train_params)
  predicted_training_loader_2 = DataLoader(get_predictions(model_2, self_training_loader_2, model_name="model_2"), **train_params)
  early_stopper = EarlyStopper(patience=3, min_delta=0.01)
  for round in range(rounds):
    print(f"Training round: {round + 1}")
    for epoch in range(self_epochs):
      print(f"Training epoch: {epoch + 1}")
      print(f"...Training Model 1 on {predicted_training_loader_2.dataset.model_name}'s predictions")
      train(model_1, optimizer_1, predicted_training_loader_2, epoch, gold=False)
      print(f"...Training Model 2 on {predicted_training_loader_1.dataset.model_name}'s predictions")
      train(model_2, optimizer_2, predicted_training_loader_1, epoch, gold=False)
      if is_validation:
        print("MODEL 1 VALIDATION")
        loss_1, labels, predictions = valid(model_1, validation_loader)
        print(classification_report([labels], [predictions]))
        #eval_concepts(model_1, test_block_loader)
        print("MODEL 2 VALIDATION")
        loss_2, labels, predictions = valid(model_2, validation_loader)
        print(classification_report([labels], [predictions]))
        #eval_concepts(model_2, test_block_loader)
      print("MODEL 1 TEST")
      loss_1, labels, predictions = valid(model_1, testing_loader)
      print(classification_report([labels], [predictions]))
      #eval_concepts(model_1, test_block_loader)
      print("MODEL 2 TEST")
      loss_2, labels, predictions = valid(model_2, testing_loader)
      print(classification_report([labels], [predictions]))
      #eval_concepts(model_2, test_block_loader)
    self_training_loader_1, self_training_loader_2 = self_training_loader_2, self_training_loader_1
    if is_validation:
        print("MODEL 1 VALIDATION")
        loss_1, labels, predictions = valid(model_1, validation_loader)
        print(classification_report([labels], [predictions]))
        #eval_concepts(model_1, test_block_loader)
        print("MODEL 2 VALIDATION")
        loss_2, labels, predictions = valid(model_2, validation_loader)
        print(classification_report([labels], [predictions]))
        #eval_concepts(model_2, test_block_loader)
        model_best = copy.deepcopy(model_1 if loss_1 < loss_2 else model_2)
        model_best.to(device)
        if early_stopper.early_stop(min(loss_1, loss_2)):
          break
    print("MODEL 1 TEST")
    loss_1, labels, predictions = valid(model_1, testing_loader)
    print(classification_report([labels], [predictions]))
    #eval_concepts(model_1, test_block_loader)
    print("MODEL 2 TEST")
    loss_2, labels, predictions = valid(model_2, testing_loader)
    print(classification_report([labels], [predictions]))
    #eval_concepts(model_2, test_block_loader)
    if is_validation:
      print("BEST MODEL TEST")
      loss_best, labels, predictions = valid(model_best, testing_loader)
      print(classification_report([labels], [predictions]))
      #eval_concepts(model_best, test_block_loader)
      if best_model_init and (round % 2 == 1 or round == ROUNDS - 1):
        model_1 = copy.deepcopy(model_best)
        model_2 = copy.deepcopy(model_best)
        model_1.to(device)
        model_2.to(device)
        optimizer_1 = torch.optim.Adam(params=model_1.parameters(), lr=LEARNING_RATE)
        optimizer_2 = torch.optim.Adam(params=model_2.parameters(), lr=LEARNING_RATE)

    predicted_training_loader_1 = DataLoader(get_predictions(model_1, self_training_loader_1, model_name="model_1"), **train_params)
    predicted_training_loader_2 = DataLoader(get_predictions(model_2, self_training_loader_2, model_name="model_2"), **train_params)
  return model_best
def ts_self_train(teacher_model, student_model, teacher_optimizer, student_optimizer, self_training_loader, validation_loader, rounds, self_epochs):
  predicted_training_loader = DataLoader(get_predictions(teacher_model, self_training_loader, model_name="teacher_model"), **train_params)
  early_stopper_round = EarlyStopper(patience=3, min_delta=0.01)
  for round in range(rounds):
    print(f"Training round: {round + 1}")
    early_stopper = EarlyStopper(patience=3, min_delta=0.01)
    for epoch in range(self_epochs):
      print(f"Training epoch: {epoch + 1}")
      print(f"...Training student_model on {predicted_training_loader.dataset.model_name}'s predictions")
      train(student_model, student_optimizer, predicted_training_loader, epoch, gold=False)
      if is_validation:
        print("STUDENT VALIDATION")
        loss, labels, predictions = valid(student_model, validation_loader)
        print(classification_report([labels], [predictions]))
        #eval_concepts(student_model, test_block_loader)
        if early_stopper.early_stop(loss):
          break
      print("STUDENT MODEL TEST")
      loss, labels, predictions = valid(student_model, testing_loader)
      print(classification_report([labels], [predictions]))
      #eval_concepts(student_model, test_block_loader)
    print(f"ROUND {round} COMPLETE!")
    teacher_model = copy.deepcopy(student_model)
    if is_validation:
      print("STUDENT VALIDATION")
      loss, labels, predictions = valid(student_model, validation_loader)
      print(classification_report([labels], [predictions]))
      #eval_concepts(student_model, test_block_loader)
      if early_stopper_round.early_stop(loss):
        break
    print("STUDENT MODEL TEST")
    loss, labels, predictions = valid(student_model, testing_loader)
    print(classification_report([labels], [predictions]))
    #eval_concepts(student_model, test_block_loader)
    predicted_training_loader = DataLoader(get_predictions(teacher_model, self_training_loader, model_name="teacher_model"), **train_params)
  return student_model
if self_training_type == "p2p":
  model_best=p2p_self_train(model_1, model_2, model_best, optimizer_1, optimizer_2, self_training_loader_1, self_training_loader_2, validation_loader, rounds=ROUNDS, self_epochs=SELF_TRAIN_EPOCH, best_model_init=best_model_init)
elif self_training_type == "ts":
  model_best=ts_self_train(teacher_model=model_1, student_model=model_2, teacher_optimizer=optimizer_1, student_optimizer=optimizer_2, self_training_loader=self_training_loader, validation_loader=validation_loader, rounds=ROUNDS, self_epochs=SELF_TRAIN_EPOCH)
# Out:
# Training round: 1
# Training epoch: 1
# ...Training student_model on teacher_model's predictions
# Training loss per 100 training steps: 0.027964100241661072
# Training loss per 100 training steps: 0.013893163809091738
# Training loss per 100 training steps: 0.014322738472455696
# Training loss per 100 training steps: 0.013915067093069371
# Training loss per 100 training steps: 0.013977241519480906
# Training loss epoch: 0.013977241519480906
# Training accuracy epoch: 0.9795702556349547
# STUDENT VALIDATION
# Validation loss per 100 evaluation steps: 0.03717029094696045
# {(6975, 6976), (8035, 8036), (3046, 3047), (9426, 9427), (3257, 3258), (5859, 5860), (2518, 2519), (10468, 10469), (2610, 2611), (3969, 3970), (10427, 10428), (628, 629), (9427, 9428), (11258, 11259), (132, 133), (2189, 2190), (4608, 4609), (10988, 10989), (1551, 1552), (4741, 4742), (41, 42), (812, 813), (8252, 8253), (7739, 7740), (12062, 12063), (12760, 12761), (3204, 3205), (4264, 4265), (12365, 12366), (10006, 10007), (166, 167), (2585, 2586), (5775, 5776), (6546, 6547), (11476, 11477), (8167, 8168), (8755, 8756), (9348, 9350), (10586, 10587), (2618, 2619), (5220, 5221), (2901, 2907), (7957, 7958), (3330, 3331), (11147, 11148), (11509, 11510), (4523, 4524), (2683, 2684), (2894, 2895), (6084, 6085), (7853, 7855), (734, 736), (11180, 11181), (5814, 5815), (5254, 5255), (4426, 4429), (4563, 4565), (2565, 2566), (8536, 8537), (10987, 10988), (5227, 5228), (7738, 7739), (8326, 8327), (5128, 5133), (5756, 5757), (358, 359), (6118, 6119), (390, 391), (601, 602), (4489, 4490), (5109, 5110), (1070, 1071), (8510, 8511), (741, 743), (4991, 4993), (2599, 2600), (602, 603), (6641, 6644), (5261, 5262), (12612, 12615), (1222, 1223), (12790, 12792), (2923, 2926), (3145, 3146), (8392, 8393), (10223, 10224), (635, 636), (10903, 10904), (715, 717), (6974, 6975), (5175, 5176), (5354, 5355), (2196, 2197), (3917, 3918), (11146, 11147), (5235, 5236), (11615, 11616), (819, 820), (6265, 6267), (2876, 2877), (3647, 3648), (1439, 1440), (7778, 7779), (6427, 6433), (11179, 11180), (11767, 11768), (2817, 2818), (4648, 4649), (7476, 7477), (12538, 12539), (7930, 7931), (2170, 2171), (10071, 10076), (7022, 7023), (10212, 10213), (3093, 3094), (4562, 4563), (5150, 5151), (5361, 5362), (11563, 11565), (8206, 8207), (6833, 6836), (826, 827), (7693, 7694), (11062, 11063), (3277, 3278), (1767, 1768), (7753, 7754), (4806, 4807), (2598, 2599), (7845, 7846), (2447, 2448), (7694, 7695), (10884, 10885), (12135, 12141), (6955, 6956), (2738, 2740), (120, 121), (10356, 10357), (3898, 3899), (4990, 4991), (3857, 3858), (4807, 4808), (11958, 11959), (1011, 1012), (12899, 12900), (2361, 2362), (5368, 5369), (3931, 3932), (9362, 9364), (590, 591), (3041, 3042), (2664, 2665), (7879, 7880), (4433, 4435), (4721, 4722), (10891, 10893), (11252, 11253), (11840, 11841), (2573, 2574), (12630, 12631), (8003, 8004), (11193, 11194), (8214, 8215), (10470, 10472), (623, 624), (10514, 10515), (8306, 8307), (3134, 3135), (9624, 9625), (7054, 7055), (7176, 7179), (8004, 8005), (11194, 11195), (1748, 1749), (5149, 5150), (160, 161), (1446, 1447), (12815, 12816), (12076, 12077), (1749, 1750), (5333, 5334), (2580, 2581), (3200, 3201), (4880, 4881), (9539, 9540), (9052, 9053), (2704, 2705), (9750, 9751), (313, 314), (12091, 12092), (11511, 11517), (8162, 8163), (9993, 9994), (4193, 4198), (10975, 10976), (8453, 8455), (10872, 10874), (8254, 8255), (2856, 2857), (12142, 12143), (11614, 11615), (6548, 6550), (12083, 12084), (589, 590), (4566, 4568), (5086, 5089), (2106, 2108), (4525, 4527), (8406, 8407), (6079, 6080), (5356, 5358), (1017, 1018), (12386, 12387), (168, 169), (10587, 10588), (8196, 8197), (2436, 2437), (1109, 1110), (622, 623), (9421, 9422), (10890, 10891), (7549, 7550), (1091, 1092), (5341, 5342), (11510, 11511), (10211, 10212), (5060, 5063), (8412, 8413), (8261, 8262), (12921, 12923), (3074, 3075), (2561, 2562), (6843, 6844), (1445, 1446), (1083, 1084), (4635, 4636), (5255, 5256), (445, 446), (11562, 11563), (12544, 12545), (10924, 10925), (11544, 11545), (2594, 2595), (10805, 10806), (11016, 11017), (9705, 9707), (5256, 5257), (629, 630), (11636, 11637), (7707, 7708), (11806, 11807), (3339, 3341), (2778, 2779), (3838, 3839), (5197, 5198), (5750, 5756), (7028, 7029), (8387, 8388), (10806, 10807), (5440, 5441), (268, 269), (9738, 9740), (7708, 7709), (6271, 6272), (8328, 8329), (2191, 2192), (5441, 5442), (6910, 6911), (5473, 5474), (7892, 7893), (9572, 9573), (7773, 7774), (2192, 2193), (11783, 11786), (3945, 3946), (11023, 11024), (2467, 2468), (4524, 4525), (5474, 5475), ( ...
# {(6975, 6976), (8035, 8036), (6646, 6648), (3257, 3258), (10124, 10125), (687, 688), (10427, 10428), (3969, 3970), (12558, 12560), (628, 629), (1432, 1434), (4139, 4140), (9427, 9428), (11258, 11259), (132, 133), (2189, 2190), (11609, 11611), (41, 42), (812, 813), (1510, 1511), (5062, 5063), (7602, 7604), (8252, 8253), (12030, 12031), (7739, 7740), (12760, 12761), (8392, 8394), (12365, 12366), (74, 75), (12095, 12096), (166, 167), (5775, 5776), (10526, 10527), (11476, 11477), (5748, 5749), (8167, 8168), (10586, 10587), (5220, 5221), (4220, 4221), (291, 292), (2710, 2711), (2901, 2907), (10921, 10922), (7957, 7958), (11147, 11148), (11509, 11510), (5598, 5599), (4523, 4524), (642, 644), (12583, 12584), (292, 293), (2894, 2895), (734, 736), (11180, 11181), (5631, 5632), (5254, 5255), (4426, 4429), (9215, 9216), (4563, 4565), (1458, 1459), (7964, 7966), (8536, 8537), (9156, 9157), (10804, 10805), (5227, 5228), (6058, 6059), (9658, 9660), (7738, 7739), (8326, 8327), (6118, 6119), (5756, 5757), (390, 391), (601, 602), (4489, 4490), (1070, 1071), (8510, 8511), (741, 743), (4991, 4993), (5789, 5790), (602, 603), (6641, 6644), (5261, 5262), (12612, 12615), (1222, 1223), (12790, 12792), (6653, 6655), (4371, 4372), (3145, 3146), (10962, 10963), (10223, 10224), (3976, 3977), (3614, 3615), (635, 636), (10903, 10904), (715, 717), (6974, 6975), (338, 340), (5354, 5355), (11146, 11147), (2196, 2197), (3917, 3918), (5235, 5236), (10256, 10257), (11615, 11616), (6265, 6267), (3647, 3648), (7609, 7611), (1439, 1440), (4998, 5000), (6427, 6433), (5570, 5571), (6645, 6646), (11179, 11180), (11767, 11768), (4648, 4649), (21, 22), (12538, 12539), (641, 642), (7930, 7931), (7978, 7980), (5571, 5572), (3093, 3094), (4562, 4563), (5150, 5151), (5512, 5513), (4193, 4199), (5361, 5362), (11563, 11565), (11851, 11852), (8206, 8207), (6833, 6836), (7693, 7694), (4016, 4017), (11062, 11063), (5302, 5303), (6726, 6728), (4806, 4807), (5577, 5578), (12623, 12624), (7845, 7846), (2447, 2448), (7694, 7695), (10884, 10885), (12135, 12141), (6955, 6956), (10145, 10146), (120, 121), (4260, 4261), (3898, 3899), (10356, 10357), (4990, 4991), (3857, 3858), (4807, 4808), (11958, 11959), (1011, 1012), (10297, 10298), (10917, 10918), (2361, 2362), (5368, 5369), (7199, 7200), (2, 3), (3041, 3042), (3813, 3815), (7879, 7880), (11840, 11841), (4433, 4435), (7793, 7795), (12630, 12631), (8003, 8004), (3, 4), (5795, 5796), (8214, 8215), (10470, 10472), (623, 624), (11193, 11194), (5493, 5494), (2697, 2698), (143, 145), (8306, 8307), (10274, 10277), (3134, 3135), (3864, 3865), (7054, 7055), (7176, 7179), (8004, 8005), (11194, 11195), (807, 808), (9565, 9566), (5149, 5150), (160, 161), (5785, 5787), (1446, 1447), (12815, 12816), (9657, 9658), (5333, 5334), (3200, 3201), (3610, 3612), (2672, 2673), (9539, 9540), (464, 465), (9052, 9053), (9750, 9751), (313, 314), (12091, 12092), (11511, 11517), (8162, 8163), (10975, 10976), (5032, 5033), (12545, 12546), (12005, 12007), (5474, 5476), (8254, 8255), (12032, 12033), (12142, 12143), (10916, 10917), (11614, 11615), (5156, 5157), (2948, 2949), (3946, 3948), (12083, 12084), (589, 590), (4566, 4568), (8406, 8407), (2106, 2108), (4525, 4527), (9177, 9178), (5097, 5098), (9875, 9876), (287, 288), (1017, 1018), (12386, 12387), (10587, 10588), (7608, 7609), (8196, 8197), (2436, 2437), (1109, 1110), (622, 623), (5869, 5870), (9421, 9422), (2711, 2712), (5492, 5493), (10890, 10891), (1091, 1092), (11510, 11511), (8412, 8413), (8261, 8262), (5939, 5943), (2383, 2385), (6843, 6844), (1445, 1446), (4635, 4636), (5045, 5047), (5255, 5256), (10004, 10007), (11562, 11563), (7755, 7758), (6674, 6675), (10924, 10925), (7604, 7607), (11544, 11545), (10805, 10806), (1567, 1569), (10444, 10446), (11016, 11017), (9705, 9707), (5256, 5257), (629, 630), (11636, 11637), (2686, 2687), (7707, 7708), (11847, 11848), (689, 690), (7556, 7557), (3339, 3341), (9236, 9237), (5750, 5756), (8387, 8388), (9738, 9740), (7708, 7709), (3081, 3082), (5500, 5501), (6271,  ...
# Validation Loss: 0.03327317405880118
# Validation Accuracy: 0.9409209577634923
# Chunk Precision: 0.6206896551724138
# Chunk Recall: 0.6969026548672567
# Chunk F1: 0.6565919749869724
#               precision    recall  f1-score   support
#
#            _       0.61      0.71      0.66       904
#
#    micro avg       0.61      0.71      0.66       904
#    macro avg       0.61      0.71      0.66       904
# weighted avg       0.61      0.71      0.66       904
#
# STUDENT MODEL TEST
# Validation loss per 100 evaluation steps: 0.004934228956699371
# Validation loss per 100 evaluation steps: 0.04412007293933922
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (19074, 19075), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (25757, 25758), (3640, 3642), (13698, 13701), (16368, 16370), (21526, 21527), (16128, 16129), (3910, 3911), (16748, 16749), (26286, 26287), (23826, 23827), (19499, 19501), (25758, 25759), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (19048, 19049), (20769, 20770), (25019, 25020), (8101, 8102), (25639, 25640), (12760, 12761), (22298, 22299), (16749, 16750), (21408, 21409), (5591, 5592), (26319, 26320), (4264, 4265), (27999, 28000), (3264, 3265), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (2107, 2111), (24162, 24163), (21304, 21306), (13624, 13625), (21441, 21442), (14156, 14160), (14622, 14624), (3054, 3055), (18384, 18385), (25613, 25614), (24103, 24104), (28426, 28427), (27703, 27705), (26806, 26807), (20884, 20887), (8167, 8168), (5959, 5960), (27973, 27974), (5220, 5221), (2256, 2257), (8410, 8411), (12347, 12353), (13625, 13626), (9980, 9981), (23195, 23196), (4220, 4221), (13749, 13750), (5749, 5750), (399, 401), (8411, 8412), (2063, 2064), (18922, 18923), (19920, 19922), (8673, 8677), (6553, 6554), (27208, 27209), (13222, 13223), (16412, 16413), (26831, 26832), (5575, 5579), (7222, 7225), (14872, 14874), (114, 115), (17275, 17276), (25680, 25681), (20330, 20332), (4833, 4834), (26621, 26622), (4227, 4228), (24143, 24144), (7635, 7637), (5967, 5968), (5605, 5606), (11759, 11760), (5228, 5229), (17157, 17158), (21297, 21298), (21407, 21408), (26805, 26806), (27636, 27637), (14647, 14648), (8299, 8300), (21437, 21439), (4958, 4959), (26048, 26049), (4471, 4472), (2599, 2600), (5201, 5202), (26728, 26729), (21330, 21331), (21440, 21441), (3840, 3842), (3053, 3054), (13472, 13473), (26898, 26899), (483, 484), (8300, 8301), (6863, 6864), (25461, 25462), (16360, 16361), (21969, 21970), (26292, 26293), (2255, 2256), (13850, 13851), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (2380, 2381), (6369, 6370), (27207, 27208), (3909, 3910), (3060, 3061), (8466, 8472), (12346, 12347), (26905, 26906), (4378, 4379), (28297, 28299), (19919, 19920), (3850, 3851), (11951, 11952), (4832, 4833), (4182, 4184), (21448, 21449), (14812, 14814), (28607, 28613), (21329, 21330), (8114, 8115), (26938, 26939), (28939, 28943), (29279, 29280), (28090, 28094), (16400, 16401), (27980, 27981), (19801, 19802), (26181, 26182), (5847, 5848), (6435, 6436), (25653, 25654), (1657, 1658), (4957, 4958), (23493, 23495), (18383, 18384), (26273, 26274), (28120, 28122), (27953, 27954), (15484, 15486), (12866, 12867), (3916, 3917), (16644, 16645), (21303, 21304), (14074, 14075), (88, 89), (13697, 13698), (6468, 6469), (120, 121), (11127, 11128), (15466, 15468), (16736, 16737), (18324, 18325), (21395, 21396), (26912, 26913), (27954, 27955), (5427, 5428), (25778, 25779), (61, 62), (3839, 3840), (11656, 11657), (17087, 17089), (27927, 27928), (18600, 18601), (24980, 24981), (13822, 13823), (8809, 8815), (19808, 19809), (25779, 25780), (5854, 5855), (6291, 6292), (5024, 5025), (26340, 26341), (5644, 5645), (13310, 13311), (5704, 5705), (16171, 16173), (748, 750), (4226, 4227), (24183, 24184), (7054, 7055), (27982, 27985), (4075, 4076), (27222, 27223), (8438, 8444), (25634, 25635), (24124, 24125), (21554, 21555), (28296, 28297), (18575, 18576), (8808, 8809), (8431, 8432), (2671, 2672), (25457, 25459), (4241, 4242), (17079, 17080), (19498, 19499), (25759, 25760), (28000, 28002), (19050, 19052), (14601, 14602), (14073, 14074), (26911, 26912), (16130, 16131), (19682, 19683), (21739, 21740), (28270, 28271), (28119, 28120), (19169, 19170), (19774, 19775), (25760, 25761), (27229, 27230), (14602, 14603), (26742, 26743), (19261, 19262), (8465, 8466), (12674, 12678), (18884, 18885), (25852, 25853), (19930, 19933), (21923, 21924), (26793, 26794), (5216, 5217), (5463, 5466), (49, 51), (16617, 16618), (12216, 12217), (26885, 26886), (16104, 16105), (1756, 1757), (17784, 17785), (1374 ...
# Validation Loss: 0.03822718114616519
# Validation Accuracy: 0.9552780801934554
# Chunk Precision: 0.6103074141048824
# Chunk Recall: 0.5404323458767014
# Chunk F1: 0.5732484076433122
#               precision    recall  f1-score   support
#
#            _       0.60      0.54      0.57      1249
#
#    micro avg       0.60      0.54      0.57      1249
#    macro avg       0.60      0.54      0.57      1249
# weighted avg       0.60      0.54      0.57      1249
#
# Training epoch: 2
# ...Training student_model on teacher_model's predictions
# Training loss per 100 training steps: 0.007163305301219225
# Training loss per 100 training steps: 0.011014216399687056
# Training loss per 100 training steps: 0.01119274504130025
# Training loss per 100 training steps: 0.01074668959154828
# Training loss per 100 training steps: 0.01084250340904771
# Training loss epoch: 0.01084250340904771
# Training accuracy epoch: 0.9846251410213674
# STUDENT VALIDATION
# Validation loss per 100 evaluation steps: 0.01093163900077343
# {(7337, 7338), (12694, 12695), (2761, 2762), (1628, 1629), (3349, 3350), (5406, 5407), (8, 9), (6539, 6540), (5438, 5439), (9578, 9579), (12299, 12300), (7706, 7707), (7329, 7330), (132, 133), (1082, 1083), (7798, 7799), (11350, 11351), (192, 193), (8009, 8010), (5439, 5440), (8629, 8630), (3231, 3232), (9023, 9024), (10460, 10461), (661, 662), (8511, 8513), (4062, 4063), (9692, 9695), (10552, 10553), (11140, 11141), (11291, 11292), (5380, 5381), (753, 754), (2584, 2585), (376, 377), (3172, 3173), (5591, 5592), (7831, 7832), (8932, 8933), (9552, 9553), (11351, 11352), (9024, 9025), (8484, 8486), (5866, 5867), (468, 469), (8662, 8663), (3475, 3476), (8873, 8874), (10553, 10554), (9116, 9117), (8965, 8966), (11567, 11568), (5867, 5868), (5899, 5900), (9998, 9999), (1048, 1049), (10586, 10587), (12675, 12676), (2499, 2500), (3481, 3482), (339, 341), (10559, 10560), (3330, 3331), (6520, 6521), (6159, 6161), (10408, 10409), (5010, 5011), (5420, 5422), (7761, 7763), (1214, 1215), (3271, 3272), (3482, 3483), (10560, 10561), (1004, 1005), (12121, 12122), (11483, 11484), (8325, 8326), (12103, 12104), (10305, 10307), (815, 818), (2824, 2826), (3396, 3397), (9156, 9157), (660, 661), (3488, 3489), (509, 510), (7786, 7788), (6118, 6119), (7587, 7588), (5379, 5380), (5017, 5018), (3397, 3398), (7830, 7831), (4489, 4490), (4127, 4128), (7679, 7680), (8661, 8662), (6290, 6292), (9249, 9250), (3489, 3490), (8510, 8511), (1281, 1282), (4471, 4472), (7771, 7772), (542, 543), (1240, 1241), (1362, 1365), (4142, 4144), (4430, 4431), (8359, 8360), (8602, 8603), (602, 603), (2842, 2843), (3792, 3793), (2691, 2692), (4412, 4413), (5881, 5882), (3673, 3674), (3884, 3885), (3371, 3372), (6184, 6185), (2843, 2844), (3253, 3255), (5083, 5084), (6081, 6083), (1077, 1079), (8182, 8183), (7805, 7806), (819, 820), (3270, 3271), (3496, 3497), (8366, 8367), (5419, 5420), (7687, 7688), (5117, 5118), (701, 702), (8518, 8519), (11708, 11709), (9138, 9139), (6342, 6343), (944, 945), (6390, 6392), (10322, 10323), (9112, 9114), (2942, 2943), (10171, 10172), (10190, 10191), (12630, 12636), (9403, 9406), (2295, 2296), (87, 88), (8675, 8676), (10323, 10324), (5005, 5007), (12136, 12137), (28, 29), (5685, 5687), (2296, 2297), (12169, 12170), (3251, 3252), (7727, 7728), (11311, 11312), (3931, 3932), (6350, 6351), (8181, 8182), (2469, 2471), (3403, 3404), (5870, 5872), (3252, 3253), (1044, 1045), (2513, 2514), (3495, 3496), (154, 155), (2443, 2446), (35, 36), (985, 986), (5072, 5074), (8457, 8458), (95, 96), (2514, 2515), (9514, 9515), (10574, 10575), (8004, 8005), (12375, 12377), (12874, 12875), (1018, 1019), (3469, 3470), (12316, 12318), (2790, 2791), (707, 708), (3897, 3898), (4149, 4150), (10245, 10246), (10607, 10608), (7886, 7887), (2488, 2489), (511, 513), (10337, 10338), (12168, 12169), (2369, 2370), (9111, 9112), (8372, 8373), (3562, 3563), (2704, 2705), (6844, 6845), (5366, 5367), (5954, 5955), (556, 557), (3794, 3796), (3007, 3008), (10231, 10232), (3233, 3234), (8254, 8255), (5895, 5896), (7774, 7776), (9177, 9178), (925, 926), (5065, 5066), (7305, 7306), (11056, 11058), (6079, 6080), (319, 320), (4418, 4419), (7608, 7609), (8379, 8380), (12629, 12630), (12567, 12569), (7851, 7852), (4510, 4511), (4148, 4149), (5869, 5870), (2890, 2891), (5492, 5493), (6080, 6081), (320, 321), (8698, 8700), (11570, 11571), (7641, 7642), (9410, 9412), (5071, 5072), (3561, 3562), (8520, 8522), (504, 505), (1202, 1203), (8353, 8354), (463, 464), (7825, 7826), (596, 597), (10244, 10245), (4484, 4485), (11814, 11815), (10336, 10337), (1024, 1025), (7766, 7767), (8354, 8355), (4668, 4669), (478, 479), (11485, 11486), (4366, 4367), (689, 690), (7767, 7768), (3838, 3839), (6330, 6331), (7799, 7800), (8387, 8388), (3971, 3972), (3609, 3610), (42, 43), (3232, 3233), (3930, 3931), (11990, 11991), (3340, 3342), (11141, 11142), (8933, 8934), (10219, 10220), (5592, 5593), (9192, 9194), (814, 815), (10311, 10312), (7043, 7044), (8874, 8875), (11702, 11703), (12400, 12401), (7622, 7623), (1117 ...
# {(2836, 2838), (7337, 7338), (11996, 11997), (12694, 12695), (2761, 2762), (3349, 3350), (2987, 2988), (6539, 6540), (8, 9), (8008, 8009), (5438, 5439), (12299, 12300), (628, 629), (12029, 12030), (12727, 12728), (1082, 1083), (12089, 12090), (7798, 7799), (11350, 11351), (192, 193), (8009, 8010), (8629, 8630), (2281, 2282), (3231, 3232), (9023, 9024), (661, 662), (8511, 8513), (4062, 4063), (7362, 7363), (9692, 9695), (10552, 10553), (11140, 11141), (5380, 5381), (753, 754), (2584, 2585), (5591, 5592), (7831, 7832), (8932, 8933), (11351, 11352), (9024, 9025), (8484, 8486), (5866, 5867), (468, 469), (8662, 8663), (8873, 8874), (10553, 10554), (11324, 11325), (8015, 8016), (8965, 8966), (11567, 11568), (5867, 5868), (7924, 7925), (5899, 5900), (9998, 9999), (8016, 8017), (12675, 12676), (458, 460), (8847, 8848), (2499, 2500), (8108, 8109), (3481, 3482), (339, 341), (7369, 7370), (11298, 11299), (3330, 3331), (6520, 6521), (351, 352), (6159, 6161), (5010, 5011), (5420, 5422), (10408, 10409), (11978, 11979), (12129, 12130), (5841, 5842), (8130, 8133), (9242, 9243), (3482, 3483), (10349, 10350), (2986, 2987), (12524, 12525), (8233, 8234), (233, 234), (1004, 1005), (12121, 12122), (12373, 12374), (11483, 11484), (8325, 8326), (2927, 2928), (12103, 12104), (357, 358), (6985, 6989), (815, 818), (2824, 2826), (8056, 8058), (827, 829), (5664, 5665), (660, 661), (509, 510), (2928, 2929), (7587, 7588), (5379, 5380), (5017, 5018), (11759, 11760), (3397, 3398), (7830, 7831), (8661, 8662), (6290, 6292), (9249, 9250), (11306, 11307), (8510, 8511), (10231, 10232), (7771, 7772), (542, 543), (1240, 1241), (1362, 1365), (4142, 4144), (4430, 4431), (8359, 8360), (8602, 8603), (602, 603), (2842, 2843), (3792, 3793), (634, 635), (11760, 11761), (2691, 2692), (4412, 4413), (5881, 5882), (3673, 3674), (7712, 7713), (8211, 8214), (3884, 3885), (8149, 8150), (11339, 11340), (9131, 9132), (11733, 11734), (3371, 3372), (5072, 5075), (6184, 6185), (2843, 2844), (3253, 3255), (5083, 5084), (12372, 12373), (3706, 3707), (8182, 8183), (11734, 11735), (7805, 7806), (11977, 11978), (819, 820), (3647, 3648), (3496, 3497), (10348, 10349), (8366, 8367), (5387, 5388), (11877, 11878), (5419, 5420), (12387, 12388), (11287, 11289), (5117, 5118), (7719, 7720), (8019, 8021), (701, 702), (3729, 3732), (8518, 8519), (11708, 11709), (9138, 9139), (944, 945), (582, 583), (6390, 6392), (431, 432), (642, 643), (5663, 5664), (7720, 7721), (10322, 10323), (11304, 11305), (9112, 9114), (10190, 10191), (12630, 12636), (9403, 9406), (5485, 5486), (87, 88), (10323, 10324), (11305, 11306), (28, 29), (5836, 5838), (10296, 10297), (8835, 8841), (11294, 11296), (8148, 8149), (7786, 7787), (11338, 11339), (3747, 3748), (12169, 12170), (3251, 3252), (8698, 8701), (11279, 11280), (2151, 2153), (7849, 7852), (3931, 3932), (6350, 6351), (8181, 8182), (8952, 8953), (12730, 12731), (2270, 2271), (3252, 3253), (1044, 1045), (682, 683), (2513, 2514), (3495, 3496), (7760, 7761), (11312, 11313), (7021, 7022), (8953, 8954), (3303, 3304), (35, 36), (985, 986), (8457, 8458), (7324, 7325), (95, 96), (2514, 2515), (1077, 1078), (9514, 9515), (10574, 10575), (8004, 8005), (12375, 12377), (12874, 12875), (10304, 10305), (3469, 3470), (4577, 4579), (8128, 8129), (10396, 10397), (10607, 10608), (707, 708), (3897, 3898), (4149, 4150), (630, 632), (10245, 10246), (9019, 9020), (10488, 10489), (2488, 2489), (511, 513), (10337, 10338), (8129, 8130), (12168, 12169), (7390, 7391), (9111, 9112), (8372, 8373), (10489, 10490), (6844, 6845), (6441, 6442), (5366, 5367), (5954, 5955), (556, 557), (7391, 7392), (2435, 2437), (3007, 3008), (3233, 3234), (11293, 11294), (5895, 5896), (7774, 7776), (3646, 3647), (5005, 5006), (8406, 8407), (9177, 9178), (11056, 11058), (5065, 5066), (7305, 7306), (7228, 7230), (3299, 3301), (4658, 4660), (319, 320), (6079, 6080), (8379, 8380), (12629, 12630), (12567, 12569), (4510, 4511), (4148, 4149), (5869, 5870), (2890, 2891), (6080, 6081), (12327, 12328), (320, 321), (2922, 2923), ( ...
# Validation Loss: 0.03842262276254284
# Validation Accuracy: 0.943149525156396
# Chunk Precision: 0.6089494163424124
# Chunk Recall: 0.6924778761061947
# Chunk F1: 0.6480331262939959
#               precision    recall  f1-score   support
#
#            _       0.60      0.70      0.65       904
#
#    micro avg       0.60      0.70      0.65       904
#    macro avg       0.60      0.70      0.65       904
# weighted avg       0.60      0.70      0.65       904
#
# STUDENT MODEL TEST
# Validation loss per 100 evaluation steps: 0.013132622465491295
# Validation loss per 100 evaluation steps: 0.05633744910283165
# {(4697, 4700), (25514, 25515), (9988, 9990), (3640, 3642), (16368, 16370), (3910, 3911), (5590, 5591), (26939, 26941), (8101, 8102), (8932, 8933), (21408, 21409), (5591, 5592), (5623, 5624), (12521, 12524), (21441, 21442), (5624, 5625), (25613, 25614), (18384, 18385), (28426, 28427), (8167, 8168), (13749, 13750), (5981, 5983), (6553, 6554), (13222, 13223), (26831, 26832), (7705, 7706), (14872, 14874), (25680, 25681), (735, 737), (12103, 12104), (17084, 17089), (23472, 23473), (24594, 24596), (768, 770), (17157, 17158), (24084, 24085), (8299, 8300), (26048, 26049), (6911, 6914), (21330, 21331), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6124, 6125), (16360, 16361), (13850, 13851), (23043, 23044), (6125, 6126), (18601, 18602), (1169, 1171), (16696, 16697), (4832, 4833), (21448, 21449), (28607, 28613), (8130, 8132), (28090, 28094), (26181, 26182), (16460, 16461), (25653, 25654), (7106, 7107), (16828, 16829), (6290, 6291), (16526, 16527), (27927, 27928), (2680, 2682), (27982, 27985), (4167, 4168), (23275, 23276), (28296, 28297), (18575, 18576), (16399, 16400), (13619, 13620), (1690, 1691), (19169, 19170), (16163, 16164), (2619, 2621), (28097, 28101), (4267, 4268), (5626, 5627), (26188, 26189), (8169, 8170), (29278, 29279), (13719, 13720), (21553, 21554), (1822, 1823), (6555, 6557), (24592, 24593), (23459, 23460), (24593, 24594), (21284, 21285), (478, 479), (3838, 3839), (23795, 23796), (27665, 27666), (10747, 10748), (5230, 5231), (6910, 6911), (21318, 21319), (28831, 28832), (26069, 26070), (24994, 24995), (275, 277), (23045, 23046), (26933, 26934), (16169, 16170), (25607, 25608), (16170, 16171), (21449, 21450), (9232, 9234), (4834, 4835), (4306, 4307), (5968, 5969), (4835, 4836), (8209, 8210), (26508, 26511), (9878, 9880), (12057, 12061), (473, 475), (2693, 2694), (29310, 29314), (24362, 24363), (23229, 23230), (21021, 21022), (11635, 11636), (4406, 4407), (24093, 24094), (18817, 18820), (18576, 18577), (24126, 24127), (24957, 24958), (16401, 16402), (10852, 10853), (24127, 24128), (16963, 16965), (26670, 26671), (19441, 19442), (13687, 13689), (6746, 6747), (26175, 26176), (14519, 14521), (14570, 14572), (28719, 28720), (5705, 5706), (14293, 14294), (4076, 4077), (29280, 29281), (18731, 18734), (12967, 12968), (27073, 27074), (21286, 21287), (21287, 21288), (790, 792), (26308, 26309), (25492, 25493), (24964, 24965), (5586, 5587), (16139, 16140), (7000, 7003), (21721, 21722), (14492, 14493), (25609, 25610), (18380, 18381), (4264, 4267), (2595, 2596), (6483, 6484), (29253, 29254), (5667, 5669), (15903, 15905), (21722, 21723), (12864, 12865), (4308, 4309), (4837, 4838), (25646, 25649), (24298, 24299), (16541, 16542), (21788, 21789), (26809, 26810), (4374, 4375), (2713, 2714), (6853, 6854), (26810, 26811), (16272, 16273), (4375, 4376), (24332, 24333), (4407, 4408), (18815, 18816), (16866, 16868), (9925, 9926), (4408, 4409), (7221, 7222), (571, 572), (4171, 4173), (12166, 12167), (18320, 18321), (7782, 7783), (3869, 3871), (15270, 15272), (26078, 26079), (26909, 26910), (17213, 17218), (5608, 5609), (13668, 13669), (16167, 16169), (14218, 14221), (5641, 5642), (18376, 18378), (12600, 12601), (6479, 6481), (4013, 4014), (12601, 12602), (2624, 2626), (5725, 5726), (25682, 25683), (28980, 28982), (8746, 8747), (29250, 29251), (5726, 5727), (4337, 4339), (27074, 27075), (11836, 11837), (21288, 21290), (29316, 29318), (16311, 16312), (1860, 1862), (18822, 18823), (6320, 6321), (25749, 25750), (13582, 13583), (24951, 24952), (26310, 26311), (24102, 24103), (26613, 26614), (18888, 18889), (25815, 25816), (21377, 21381), (72, 73), (16462, 16463), (28089, 28090), (6755, 6756), (26184, 26185), (29255, 29256), (8165, 8166), (2616, 2617), (14276, 14278), (18408, 18414), (24300, 24302), (4613, 4614), (12641, 12642), (12673, 12674), (22941, 22942), (5991, 5992), (9030, 9031), (26811, 26812), (3287, 3288), (27919, 27921), (7944, 7946), (3848, 3849), (11876, 11877), (26284, 26285), (26316, 26317), (21554, 21556), (3849, 3850), (8301 ...
# {(2064, 2065), (19074, 19075), (12056, 12057), (21736, 21737), (25514, 25515), (18395, 18396), (26285, 26286), (10748, 10752), (25757, 25758), (16368, 16370), (21526, 21527), (4970, 4971), (16748, 16749), (26286, 26287), (23826, 23827), (19499, 19501), (25758, 25759), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (19048, 19049), (483, 485), (20769, 20770), (25019, 25020), (25639, 25640), (12760, 12761), (25850, 25851), (21408, 21409), (26319, 26320), (4264, 4265), (27999, 28000), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (2107, 2111), (24162, 24163), (21304, 21306), (21441, 21442), (14156, 14160), (14622, 14624), (3054, 3055), (18384, 18385), (25613, 25614), (24103, 24104), (28426, 28427), (27703, 27705), (26806, 26807), (20884, 20887), (8167, 8168), (27973, 27974), (5220, 5221), (2256, 2257), (12347, 12353), (13625, 13626), (23195, 23196), (4220, 4221), (13749, 13750), (399, 401), (2063, 2064), (18922, 18923), (19920, 19922), (8673, 8677), (6553, 6554), (27208, 27209), (13222, 13223), (26831, 26832), (7222, 7225), (14872, 14874), (114, 115), (17092, 17093), (25680, 25681), (20330, 20332), (4833, 4834), (26621, 26622), (4227, 4228), (24143, 24144), (7635, 7637), (17157, 17158), (5605, 5606), (11759, 11760), (5228, 5229), (21297, 21298), (21407, 21408), (26805, 26806), (27636, 27637), (8299, 8300), (21437, 21439), (4958, 4959), (26048, 26049), (4471, 4472), (2599, 2600), (5201, 5202), (26728, 26729), (21330, 21331), (21440, 21441), (3840, 3842), (3053, 3054), (26898, 26899), (8300, 8301), (6863, 6864), (16360, 16361), (21969, 21970), (26292, 26293), (2255, 2256), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (27207, 27208), (8466, 8472), (12346, 12347), (26905, 26906), (4378, 4379), (28297, 28299), (19919, 19920), (11951, 11952), (4832, 4833), (4182, 4184), (21448, 21449), (28607, 28613), (21329, 21330), (8114, 8115), (26938, 26939), (6132, 6133), (28939, 28943), (29279, 29280), (28090, 28094), (16400, 16401), (25021, 25023), (19801, 19802), (27980, 27981), (26181, 26182), (16460, 16461), (5847, 5848), (25653, 25654), (1657, 1658), (4957, 4958), (23493, 23495), (18383, 18384), (26273, 26274), (28120, 28122), (27953, 27954), (9355, 9356), (15484, 15486), (12866, 12867), (3916, 3917), (21303, 21304), (14074, 14075), (18324, 18325), (26912, 26913), (6468, 6469), (120, 121), (11127, 11128), (15466, 15468), (21395, 21396), (27954, 27955), (4839, 4840), (5427, 5428), (25778, 25779), (61, 62), (8431, 8437), (3839, 3840), (11656, 11657), (17087, 17089), (18885, 18886), (27927, 27928), (18600, 18601), (13822, 13823), (8809, 8815), (19808, 19809), (25779, 25780), (5854, 5855), (6291, 6292), (5024, 5025), (5644, 5645), (25812, 25813), (13310, 13311), (5704, 5705), (16171, 16173), (4226, 4227), (24183, 24184), (7054, 7055), (27982, 27985), (27222, 27223), (8438, 8444), (25634, 25635), (24124, 24125), (28296, 28297), (18575, 18576), (8808, 8809), (3621, 3622), (4241, 4242), (17079, 17080), (19498, 19499), (25759, 25760), (28000, 28002), (19050, 19052), (14601, 14602), (14812, 14813), (14073, 14074), (26911, 26912), (19682, 19683), (27499, 27500), (21739, 21740), (4972, 4973), (28119, 28120), (19169, 19170), (19774, 19775), (25760, 25761), (27229, 27230), (8465, 8466), (12674, 12678), (18884, 18885), (25852, 25853), (26793, 26794), (5216, 5217), (5463, 5466), (49, 51), (16617, 16618), (4326, 4327), (16104, 16105), (21462, 21467), (1756, 1757), (17784, 17785), (13745, 13746), (16347, 16348), (12629, 12630), (28097, 28101), (4267, 4268), (16817, 16819), (29245, 29246), (26188, 26189), (13309, 13310), (16137, 16138), (18918, 18919), (16348, 16349), (8169, 8170), (4240, 4241), (22939, 22940), (6131, 6132), (29278, 29279), (83, 85), (261, 262), (18891, 18892), (21022, 21024), (13719, 13720), (27690, 27691), (11511, 11512), (14113, 14114), (26180, 26181), (11953, 11955), (13601, 13603), (24592, 24593), (26183, 26186), (2065, 2066), (21251, 21252), (26272, 26273), (1181 ...
# Validation Loss: 0.04717692062044866
# Validation Accuracy: 0.9564838618021222
# Chunk Precision: 0.6224814422057264
# Chunk Recall: 0.4699759807846277
# Chunk F1: 0.5355839416058394
#               precision    recall  f1-score   support
#
#            _       0.61      0.47      0.53      1249
#
#    micro avg       0.61      0.47      0.53      1249
#    macro avg       0.61      0.47      0.53      1249
# weighted avg       0.61      0.47      0.53      1249
#
# Training epoch: 3
# ...Training student_model on teacher_model's predictions
# Training loss per 100 training steps: 0.008395526558160782
# Training loss per 100 training steps: 0.007803681975064597
# Training loss per 100 training steps: 0.008282971624441362
# Training loss per 100 training steps: 0.008554906444604729
# Training loss per 100 training steps: 0.009160589685351786
# Training loss epoch: 0.009160589685351786
# Training accuracy epoch: 0.986867880656786
# STUDENT VALIDATION
# Validation loss per 100 evaluation steps: 0.05414672940969467
# {(1577, 1578), (67, 68), (1536, 1537), (4028, 4029), (5708, 5709), (9486, 9487), (2079, 2081), (10955, 10956), (3592, 3593), (5649, 5650), (7949, 7950), (4121, 4122), (4851, 4852), (5650, 5651), (12030, 12031), (11291, 11292), (7950, 7951), (2012, 2014), (5742, 5743), (753, 754), (4013, 4018), (4641, 4642), (8344, 8345), (6232, 6235), (3021, 3022), (4852, 4853), (3415, 3416), (5834, 5835), (9374, 9376), (9552, 9553), (12365, 12366), (12262, 12264), (11475, 11476), (694, 695), (317, 318), (365, 367), (786, 787), (11205, 11206), (47, 48), (3416, 3417), (9407, 9409), (11372, 11375), (1089, 1090), (11325, 11326), (4128, 4129), (2256, 2257), (10829, 10830), (12399, 12400), (2348, 2349), (7218, 7219), (6143, 6144), (11239, 11240), (4120, 4121), (5841, 5842), (81, 82), (12221, 12222), (2894, 2895), (5722, 5723), (2592, 2593), (11180, 11181), (1155, 1156), (8201, 8202), (11423, 11424), (4194, 4195), (12121, 12122), (11272, 11273), (1945, 1946), (2927, 2928), (4286, 4287), (7192, 7193), (11332, 11333), (12122, 12123), (1834, 1840), (1188, 1189), (6225, 6227), (449, 450), (266, 267), (3456, 3457), (1248, 1249), (1868, 1869), (4807, 4809), (11759, 11760), (450, 451), (5471, 5472), (7528, 7529), (1979, 1980), (2872, 2875), (2961, 2962), (6151, 6152), (10039, 10040), (3403, 3405), (11792, 11793), (3430, 3431), (10902, 10903), (10751, 10752), (5353, 5354), (181, 182), (2255, 2256), (11793, 11794), (4312, 4313), (9223, 9224), (6065, 6066), (5354, 5355), (608, 609), (5629, 5630), (819, 820), (4009, 4010), (1926, 1927), (5478, 5479), (8274, 8275), (8485, 8486), (7048, 7049), (1650, 1651), (10876, 10877), (11238, 11239), (7007, 7008), (549, 550), (2018, 2019), (11767, 11768), (11877, 11878), (2078, 2079), (6989, 6990), (10877, 10878), (5479, 5480), (9440, 9441), (11088, 11089), (129, 131), (5511, 5512), (12317, 12320), (12346, 12347), (582, 583), (2413, 2414), (3983, 3984), (6040, 6041), (9551, 9552), (12091, 12093), (6981, 6982), (7963, 7964), (2414, 2415), (10474, 10475), (675, 676), (5696, 5697), (11094, 11095), (12486, 12488), (7964, 7965), (4806, 4807), (11774, 11775), (3429, 3430), (10296, 10297), (2328, 2329), (1195, 1196), (120, 121), (9994, 9995), (11338, 11339), (9255, 9256), (11529, 11535), (180, 181), (1649, 1650), (1287, 1288), (7047, 7048), (10599, 10600), (12169, 12170), (10297, 10298), (2329, 2330), (10917, 10918), (6988, 6989), (12261, 12262), (11538, 11540), (7199, 7200), (9691, 9692), (11522, 11523), (590, 591), (2421, 2422), (10270, 10271), (5460, 5461), (5309, 5310), (3495, 3496), (4193, 4194), (12553, 12555), (3436, 3437), (2125, 2127), (9532, 9533), (10482, 10483), (1564, 1565), (5342, 5343), (8155, 8156), (11345, 11346), (4846, 4847), (5434, 5435), (36, 37), (1867, 1868), (5300, 5301), (4787, 4788), (9506, 9507), (8280, 8281), (11319, 11320), (11551, 11554), (4788, 4789), (11168, 11169), (4820, 4821), (9370, 9372), (12242, 12243), (1084, 1085), (12453, 12454), (5743, 5744), (9993, 9994), (2025, 2026), (10916, 10917), (11504, 11505), (8346, 8347), (9296, 9297), (6726, 6727), (3056, 3058), (12216, 12217), (2889, 2890), (12537, 12538), (4795, 4796), (8347, 8348), (6718, 6719), (6231, 6232), (2890, 2891), (1091, 1092), (3510, 3511), (12888, 12889), (1394, 1395), (6053, 6054), (293, 294), (1941, 1942), (2124, 2125), (8520, 8522), (10891, 10892), (7294, 7296), (11360, 11361), (11754, 11755), (12452, 12453), (8262, 8263), (4333, 4334), (537, 538), (2006, 2007), (6087, 6088), (11156, 11158), (4868, 4870), (9369, 9370), (7271, 7272), (8630, 8631), (8228, 8233), (11788, 11789), (11898, 11899), (8479, 8480), (2342, 2343), (7951, 7952), (360, 361), (7061, 7062), (603, 604), (2072, 2073), (2251, 2252), (3022, 3023), (9480, 9481), (11281, 11283), (4340, 4341), (5322, 5323), (2343, 2344), (544, 545), (4794, 4795), (5382, 5383), (755, 756), (6851, 6852), (9664, 9665), (9513, 9514), (10872, 10873), (5474, 5475), (6943, 6944), (3886, 3887), (8168, 8169), (9454, 9455), (8017, 8018), (5658, 5659), (7017, 7018), (8109, 8110), (4029, 4030), ( ...
# {(1577, 1578), (1536, 1537), (4028, 4029), (5708, 5709), (9486, 9487), (10955, 10956), (7159, 7160), (5649, 5650), (6237, 6238), (5347, 5348), (9881, 9882), (4121, 4122), (3991, 3994), (11021, 11023), (240, 242), (4851, 4852), (5650, 5651), (1023, 1024), (8252, 8253), (8300, 8302), (8101, 8102), (11291, 11292), (5531, 5532), (5742, 5743), (8344, 8345), (753, 754), (4013, 4018), (4641, 4642), (8570, 8571), (6232, 6235), (3021, 3022), (4852, 4853), (3415, 3416), (5834, 5835), (9374, 9376), (8662, 8663), (9552, 9553), (11443, 11444), (11475, 11476), (12365, 12366), (317, 318), (3507, 3508), (8015, 8016), (786, 787), (11205, 11206), (8226, 8227), (47, 48), (997, 998), (3416, 3417), (12236, 12239), (1938, 1939), (1089, 1090), (11325, 11326), (9364, 9367), (9998, 9999), (2119, 2121), (4128, 4129), (5597, 5598), (2256, 2257), (7488, 7489), (259, 260), (12399, 12400), (2909, 2911), (5689, 5690), (7218, 7219), (6143, 6144), (5781, 5782), (5598, 5599), (8049, 8050), (9880, 9881), (4120, 4121), (5841, 5842), (11239, 11240), (12221, 12222), (5722, 5723), (11180, 11181), (8201, 8202), (11423, 11424), (4194, 4195), (12011, 12012), (12121, 12122), (11272, 11273), (1945, 1946), (8325, 8326), (2927, 2928), (4286, 4287), (7192, 7193), (9275, 9276), (10752, 10758), (11332, 11333), (1834, 1840), (8023, 8024), (12122, 12123), (12756, 12758), (1188, 1189), (6225, 6227), (449, 450), (3456, 3457), (10807, 10810), (9459, 9460), (1868, 1869), (4397, 4398), (4807, 4809), (5605, 5606), (8207, 8208), (8617, 8619), (450, 451), (9038, 9039), (7528, 7529), (1979, 1980), (2872, 2875), (8558, 8560), (2961, 2962), (6151, 6152), (7133, 7134), (9190, 9191), (3430, 3431), (10902, 10903), (7561, 7562), (10751, 10752), (5353, 5354), (9152, 9155), (2255, 2256), (4312, 4313), (9223, 9224), (5354, 5355), (11933, 11935), (10784, 10785), (9274, 9275), (2816, 2817), (608, 609), (9894, 9895), (3437, 3439), (9407, 9408), (4009, 4010), (1926, 1927), (5478, 5479), (8096, 8098), (8274, 8275), (7158, 7159), (1650, 1651), (8485, 8486), (10725, 10726), (12678, 12681), (549, 550), (2018, 2019), (5298, 5301), (10785, 10786), (2817, 2818), (11028, 11029), (2078, 2079), (6989, 6990), (5479, 5480), (9440, 9441), (8307, 8308), (129, 131), (5511, 5512), (5559, 5561), (12346, 12347), (2413, 2414), (5603, 5604), (8022, 8023), (8610, 8611), (3983, 3984), (6040, 6041), (7132, 7133), (9551, 9552), (12091, 12093), (6981, 6982), (7963, 7964), (8551, 8552), (8583, 8584), (2414, 2415), (5604, 5605), (6375, 6376), (10474, 10475), (8675, 8676), (675, 676), (5696, 5697), (12486, 12488), (12822, 12824), (4806, 4807), (7996, 7997), (8584, 8585), (8616, 8617), (3429, 3430), (10296, 10297), (5486, 5487), (88, 89), (2328, 2329), (1195, 1196), (6257, 6258), (8708, 8709), (9994, 9995), (10145, 10146), (11338, 11339), (11529, 11535), (11866, 11867), (7997, 7998), (1649, 1650), (1287, 1288), (10599, 10600), (6896, 6897), (10825, 10826), (12169, 12170), (10297, 10298), (2329, 2330), (10917, 10918), (6988, 6989), (12261, 12262), (11538, 11540), (7199, 7200), (9691, 9692), (3931, 3932), (11522, 11523), (590, 591), (2421, 2422), (5460, 5461), (5309, 5310), (10724, 10725), (8532, 8534), (4193, 4194), (8564, 8566), (397, 398), (3436, 3437), (2125, 2127), (9532, 9533), (9455, 9457), (1564, 1565), (10482, 10483), (5342, 5343), (6933, 6936), (8155, 8156), (11345, 11346), (7054, 7055), (4846, 4847), (5434, 5435), (36, 37), (1867, 1868), (5057, 5058), (7508, 7509), (4787, 4788), (5737, 5738), (9037, 9038), (9170, 9171), (9506, 9507), (8280, 8281), (7147, 7148), (11319, 11320), (4200, 4201), (4788, 4789), (8571, 8573), (11168, 11169), (4820, 4821), (3562, 3563), (9370, 9372), (12242, 12243), (1084, 1085), (3572, 3576), (5743, 5744), (5382, 5384), (6515, 6517), (9993, 9994), (12453, 12454), (2025, 2026), (4293, 4294), (6895, 6896), (1025, 1026), (2856, 2857), (11444, 11445), (8103, 8104), (10916, 10917), (8545, 8547), (11614, 11615), (8346, 8347), (346, 347), (6726, 6727), (8557, 8558), (3056, 3058), (11445, 11446), (12 ...
# Validation Loss: 0.04726271563364814
# Validation Accuracy: 0.9337212995964078
# Chunk Precision: 0.5824652777777778
# Chunk Recall: 0.7422566371681416
# Chunk F1: 0.6527237354085604
#               precision    recall  f1-score   support
#
#            _       0.58      0.75      0.65       904
#
#    micro avg       0.58      0.75      0.65       904
#    macro avg       0.58      0.75      0.65       904
# weighted avg       0.58      0.75      0.65       904
#
# STUDENT MODEL TEST
# Validation loss per 100 evaluation steps: 0.004733027890324593
# Validation loss per 100 evaluation steps: 0.048671001441215424
# ...
# {(2064, 2065), (27992, 27993), (19074, 19075), (12056, 12057), (21736, 21737), (22734, 22736), (18395, 18396), (9928, 9930), (25514, 25515), (10748, 10752), (26285, 26286), (25757, 25758), (6436, 6438), (3640, 3642), (13698, 13701), (16368, 16370), (16128, 16129), (3910, 3911), (2599, 2601), (4970, 4971), (16748, 16749), (23826, 23827), (26286, 26287), (19499, 19501), (25758, 25759), (27998, 27999), (8451, 8453), (5833, 5834), (14600, 14601), (19048, 19049), (483, 485), (6632, 6633), (20769, 20770), (23220, 23221), (12760, 12761), (23431, 23432), (7000, 7001), (25639, 25640), (16749, 16750), (20532, 20534), (21408, 21409), (26319, 26320), (4264, 4265), (27999, 28000), (3264, 3265), (4035, 4036), (16102, 16103), (25640, 25641), (17084, 17085), (2107, 2111), (1676, 1677), (14120, 14121), (24162, 24163), (21304, 21306), (13624, 13625), (21441, 21442), (14622, 14624), (3054, 3055), (18384, 18385), (25613, 25614), (24103, 24104), (28426, 28427), (27703, 27705), (26806, 26807), (14126, 14128), (20884, 20887), (8167, 8168), (27973, 27974), (5220, 5221), (2256, 2257), (12347, 12353), (13625, 13626), (23195, 23196), (4220, 4221), (13749, 13750), (399, 401), (18919, 18921), (8411, 8412), (2063, 2064), (22807, 22809), (18922, 18923), (19920, 19922), (8673, 8677), (11741, 11743), (6553, 6554), (13222, 13223), (5814, 5815), (26831, 26832), (7222, 7225), (14872, 14874), (114, 115), (25680, 25681), (23472, 23473), (20330, 20332), (4833, 4834), (26621, 26622), (4227, 4228), (24143, 24144), (7635, 7637), (17157, 17158), (21297, 21298), (21407, 21408), (26805, 26806), (27636, 27637), (8299, 8300), (21437, 21439), (26048, 26049), (4471, 4472), (5201, 5202), (26728, 26729), (21330, 21331), (21440, 21441), (3840, 3842), (3053, 3054), (8300, 8301), (25461, 25462), (6863, 6864), (16360, 16361), (21969, 21970), (25019, 25020), (26292, 26293), (2255, 2256), (14125, 14126), (24361, 24362), (18601, 18602), (29231, 29232), (4386, 4387), (4268, 4270), (2380, 2381), (14369, 14370), (6369, 6370), (27207, 27208), (3909, 3910), (18106, 18107), (12346, 12347), (28297, 28299), (19919, 19920), (3850, 3851), (11951, 11952), (4832, 4833), (4182, 4184), (14370, 14371), (28607, 28613), (21329, 21330), (8114, 8115), (21540, 21541), (6132, 6133), (28939, 28943), (29279, 29280), (28090, 28094), (19952, 19953), (25021, 25023), (19801, 19802), (27980, 27981), (26181, 26182), (16460, 16461), (5847, 5848), (6435, 6436), (25653, 25654), (24342, 24344), (1657, 1658), (4957, 4958), (22722, 22724), (18383, 18384), (23493, 23495), (5577, 5578), (27953, 27954), (9355, 9356), (28120, 28122), (3916, 3917), (16644, 16645), (22814, 22816), (21303, 21304), (14074, 14075), (18324, 18325), (26912, 26913), (6468, 6469), (120, 121), (11127, 11128), (16736, 16737), (21395, 21396), (5578, 5579), (27954, 27955), (5427, 5428), (25778, 25779), (4688, 4689), (61, 62), (8466, 8467), (3839, 3840), (11656, 11657), (17087, 17089), (27927, 27928), (18600, 18601), (13822, 13823), (8809, 8815), (19808, 19809), (25779, 25780), (5854, 5855), (6291, 6292), (5024, 5025), (26340, 26341), (13310, 13311), (5704, 5705), (16171, 16173), (25693, 25694), (748, 750), (4226, 4227), (24183, 24184), (27982, 27985), (4075, 4076), (27222, 27223), (8438, 8444), (25634, 25635), (24124, 24125), (17305, 17307), (28296, 28297), (18575, 18576), (8808, 8809), (8431, 8432), (3621, 3622), (4241, 4242), (17079, 17080), (19498, 19499), (25759, 25760), (28000, 28002), (19050, 19052), (14812, 14813), (14073, 14074), (26911, 26912), (16130, 16131), (19682, 19683), (21739, 21740), (28270, 28271), (28119, 28120), (19169, 19170), (26808, 26810), (19774, 19775), (25760, 25761), (27229, 27230), (26742, 26743), (19261, 19262), (8465, 8466), (12674, 12678), (18884, 18885), (26793, 26794), (29212, 29213), (2619, 2621), (5216, 5217), (5463, 5466), (49, 51), (15484, 15485), (12216, 12217), (16104, 16105), (1756, 1757), (17784, 17785), (13745, 13746), (16347, 16348), (28097, 28101), (4267, 4268), (16817, 16819), (29245, 29246), (26188, 26189 ...
# Validation Loss: 0.0782954740531602
# Validation Accuracy: 0.9552030048904522
# Chunk Precision: 0.6115702479338843
# Chunk Recall: 0.533226581265012
# Chunk F1: 0.5697177074422584
#               precision    recall  f1-score   support
#
#            _       0.60      0.53      0.56      1249
#
#    micro avg       0.60      0.53      0.56      1249
#    macro avg       0.60      0.53      0.56      1249
# weighted avg       0.60      0.53      0.56      1249
#
# ROUND 3 COMPLETE!
# STUDENT VALIDATION
# Validation loss per 100 evaluation steps: 0.053693853318691254
# {(1536, 1537), (10335, 10336), (7429, 7430), (10416, 10422), (7370, 7371), (4228, 4230), (4800, 4801), (9050, 9051), (5169, 5171), (8537, 8538), (2492, 2493), (4213, 4214), (12062, 12063), (10401, 10402), (5003, 5004), (11383, 11384), (12114, 12119), (2644, 2645), (468, 469), (4095, 4096), (7395, 7396), (11384, 11385), (47, 48), (258, 259), (5915, 5917), (4977, 4978), (1048, 1049), (4128, 4129), (8755, 8756), (1920, 1921), (8227, 8228), (2650, 2651), (1517, 1518), (8259, 8260), (11449, 11450), (4069, 4070), (4799, 4800), (5571, 5573), (1820, 1821), (3179, 3180), (9182, 9183), (7672, 7673), (8260, 8261), (81, 82), (10862, 10863), (11450, 11451), (4951, 4952), (1022, 1023), (22, 23), (12011, 12012), (7384, 7385), (4364, 4365), (11364, 11365), (5195, 5196), (2657, 2658), (2474, 2475), (1735, 1736), (4227, 4228), (4486, 4488), (5168, 5169), (8720, 8721), (1377, 1381), (1827, 1828), (7436, 7437), (9777, 9778), (4201, 4203), (12590, 12591), (1919, 1920), (10718, 10719), (6091, 6092), (1281, 1282), (4581, 4582), (9130, 9131), (1901, 1902), (12531, 12532), (6092, 6093), (11900, 11902), (7484, 7486), (181, 182), (3765, 3766), (12564, 12565), (11841, 11843), (6065, 6066), (4445, 4446), (5914, 5915), (1985, 1986), (2395, 2397), (4404, 4405), (7956, 7957), (1834, 1835), (8743, 8745), (7443, 7444), (8274, 8275), (12236, 12238), (3270, 3271), (5176, 5177), (7778, 7779), (2018, 2019), (6158, 6159), (8728, 8729), (11330, 11331), (12538, 12539), (21, 22), (5829, 5831), (5268, 5269), (12010, 12011), (11088, 11089), (4378, 4379), (6099, 6100), (2758, 2759), (7779, 7780), (944, 945), (7040, 7041), (2230, 2231), (10818, 10819), (4319, 4320), (8642, 8643), (10910, 10911), (4562, 4563), (11304, 11305), (523, 524), (4411, 4412), (10382, 10383), (8643, 8644), (4714, 4715), (87, 88), (675, 676), (11305, 11306), (11925, 11926), (5577, 5578), (7358, 7359), (4326, 4328), (2690, 2691), (2328, 2329), (120, 121), (2177, 2178), (8919, 8920), (7786, 7787), (4068, 4069), (5249, 5251), (1011, 1012), (3677, 3680), (1059, 1061), (7029, 7030), (12748, 12749), (10337, 10343), (8920, 8921), (1572, 1573), (12202, 12203), (11840, 11841), (8273, 8274), (1742, 1743), (4932, 4933), (10111, 10116), (12051, 12052), (7383, 7384), (8742, 8743), (2573, 2574), (5024, 5025), (397, 398), (985, 986), (1594, 1597), (3651, 3654), (246, 247), (4175, 4176), (4226, 4227), (7416, 7417), (9185, 9187), (4075, 4076), (5828, 5829), (4318, 4319), (9277, 9279), (4167, 4168), (4938, 4939), (7357, 7358), (12604, 12605), (1110, 1111), (1808, 1809), (3167, 3168), (1900, 1901), (8868, 8869), (11896, 11899), (4939, 4940), (12058, 12059), (992, 993), (4141, 4142), (5862, 5863), (5123, 5124), (7542, 7543), (2553, 2554), (4123, 4124), (4821, 4822), (7634, 7635), (8993, 8994), (10662, 10665), (10673, 10674), (11293, 11294), (9783, 9784), (2554, 2555), (10765, 10766), (11385, 11386), (438, 439), (8649, 8650), (7759, 7760), (4795, 4796), (8757, 8759), (4130, 4132), (10766, 10767), (427, 429), (2436, 2437), (8228, 8229), (12570, 12571), (1050, 1051), (12057, 12058), (9151, 9152), (23, 25), (12888, 12889), (1504, 1505), (2383, 2385), (2561, 2562), (2184, 2185), (12603, 12604), (4063, 4065), (1445, 1446), (3166, 3167), (3015, 3016), (3997, 3998), (7523, 7524), (10336, 10337), (2745, 2746), (10274, 10276), (2006, 2007), (10773, 10774), (5256, 5257), (1327, 1328), (4366, 4367), (6197, 6198), (437, 438), (4577, 4578), (8538, 8539), (7227, 7229), (2778, 2779), (8749, 8750), (6666, 6667), (7616, 7617), (9387, 9388), (10838, 10839), (42, 43), (4518, 4519), (2493, 2494), (6271, 6272), (511, 512), (10890, 10895), (4399, 4400), (7589, 7590), (11839, 11840), (4610, 4611), (2040, 2041), (2434, 2435), (10839, 10840), (8741, 8742), (11821, 11822), (9202, 9207), (2192, 2193), (8604, 8605), (2435, 2436), (5263, 5264), (1696, 1697), (4524, 4525), (10133, 10134), (2014, 2015), (8756, 8757), (1275, 1276), (4827, 4828), (6145, 6146), (8637, 8638), (3827, 3828), (4525, 4526), (3985, 3987), (12736, 12737), (1821, 1822), (2409,  ...
# {(3014, 3015), (6204, 6205), (8854, 8856), (4726, 4727), (10335, 10336), (10416, 10422), (6296, 6297), (4088, 4089), (1628, 1629), (7370, 7371), (4228, 4230), (1610, 1611), (4800, 4801), (8537, 8538), (4970, 4971), (9751, 9754), (963, 964), (1661, 1662), (2249, 2250), (5151, 5153), (5062, 5063), (2492, 2493), (4213, 4214), (12062, 12063), (1602, 1603), (10401, 10402), (5003, 5004), (11383, 11384), (12114, 12119), (6211, 6212), (1543, 1544), (468, 469), (4035, 4036), (6276, 6278), (8905, 8906), (4095, 4096), (7395, 7396), (166, 167), (1635, 1636), (11384, 11385), (4009, 4011), (7377, 7378), (258, 259), (5915, 5917), (4977, 4978), (8755, 8756), (4128, 4129), (8227, 8228), (2650, 2651), (7488, 7489), (11449, 11450), (1440, 1442), (4069, 4070), (3740, 3742), (4799, 4800), (1820, 1821), (11894, 11895), (9182, 9183), (7672, 7673), (10862, 10863), (81, 82), (2500, 2501), (11450, 11451), (4464, 4465), (22, 23), (10612, 10613), (12011, 12012), (7384, 7385), (4364, 4365), (5195, 5196), (2657, 2658), (7495, 7496), (1735, 1736), (4227, 4228), (4486, 4488), (5168, 5169), (8720, 8721), (1827, 1828), (5017, 5018), (7436, 7437), (9777, 9778), (4201, 4203), (6091, 6092), (1281, 1282), (5169, 5170), (12531, 12532), (10902, 10903), (11852, 11853), (6092, 6093), (11900, 11902), (7484, 7486), (181, 182), (4463, 4464), (11793, 11794), (12564, 12565), (6033, 6034), (4445, 4446), (5914, 5915), (1985, 1986), (2395, 2397), (4404, 4405), (3917, 3918), (1834, 1835), (8182, 8183), (7443, 7444), (12236, 12238), (306, 307), (5176, 5177), (7778, 7779), (3739, 3740), (6158, 6159), (12538, 12539), (21, 22), (1380, 1381), (3211, 3212), (5829, 5831), (11815, 11817), (12010, 12011), (4419, 4420), (4378, 4379), (12479, 12480), (5948, 5949), (7779, 7780), (944, 945), (582, 583), (2230, 2231), (10818, 10819), (4319, 4320), (8642, 8643), (12782, 12783), (10910, 10911), (6283, 6284), (11304, 11305), (523, 524), (4411, 4412), (10382, 10383), (2203, 2204), (5016, 5017), (8643, 8644), (87, 88), (675, 676), (6106, 6108), (7055, 7056), (4957, 4958), (11305, 11306), (1616, 1617), (5577, 5578), (11925, 11926), (589, 591), (3957, 3958), (5065, 5067), (7358, 7359), (4326, 4328), (2690, 2691), (120, 121), (2177, 2178), (4130, 4133), (7786, 7787), (8180, 8181), (10599, 10600), (4068, 4069), (2269, 2270), (4688, 4689), (9059, 9061), (1059, 1061), (7029, 7030), (12748, 12749), (10337, 10343), (8181, 8182), (1572, 1573), (2270, 2271), (11840, 11841), (12051, 12052), (4932, 4933), (12781, 12782), (7383, 7384), (8742, 8743), (10573, 10574), (5024, 5025), (1594, 1597), (985, 986), (12873, 12874), (246, 247), (12024, 12025), (8306, 8307), (8894, 8895), (10574, 10575), (4226, 4227), (7416, 7417), (7054, 7055), (1656, 1657), (4075, 4076), (7265, 7266), (9185, 9187), (5828, 5829), (10606, 10607), (1018, 1019), (4318, 4319), (4167, 4168), (4938, 4939), (7357, 7358), (1597, 1598), (12604, 12605), (1808, 1809), (3167, 3168), (4998, 4999), (10607, 10608), (8236, 8238), (7449, 7450), (4079, 4082), (8328, 8330), (4939, 4940), (8868, 8869), (12058, 12059), (161, 162), (1630, 1631), (6541, 6542), (992, 993), (4182, 4183), (4141, 4142), (5862, 5863), (5123, 5124), (7542, 7543), (2553, 2554), (4123, 4124), (4821, 4822), (10662, 10665), (2856, 2857), (10673, 10674), (9783, 9784), (2554, 2555), (10765, 10766), (5005, 5006), (10026, 10027), (11385, 11386), (438, 439), (8649, 8650), (4795, 4796), (10766, 10767), (4418, 4419), (10027, 10028), (3679, 3680), (427, 429), (2436, 2437), (8228, 8229), (260, 261), (10030, 10033), (12460, 12461), (12570, 12571), (12057, 12058), (5071, 5072), (1504, 1505), (7490, 7491), (2383, 2385), (2184, 2185), (3653, 3654), (12603, 12604), (1445, 1446), (3166, 3167), (12452, 12453), (6205, 6206), (5104, 5105), (2896, 2897), (10713, 10714), (10336, 10337), (10274, 10276), (10034, 10035), (5256, 5257), (1327, 1328), (2897, 2898), (4366, 4367), (437, 438), (2978, 2981), (7227, 7229), (8538, 8539), (8749, 8750), (2449, 2451), (2250, 2251), (10838, 10839), (4019, 4021), (7497, 74 ...
# Validation Loss: 0.07370647525943544
# Validation Accuracy: 0.9361930915134598
# Chunk Precision: 0.6045816733067729
# Chunk Recall: 0.6714601769911505
# Chunk F1: 0.6362683438155137
#               precision    recall  f1-score   support
#
#            _       0.60      0.69      0.64       904
#
#    micro avg       0.60      0.69      0.64       904
#    macro avg       0.60      0.69      0.64       904
# weighted avg       0.60      0.69      0.64       904

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# **evaluating the model:**

# %%
_, labels, predictions = valid(model_1, testing_loader)
print(labels[:30], predictions[:30])
print(classification_report([labels], [predictions]))
eval_concepts(model_1, test_block_loader)
_, labels, predictions = valid(model_2, testing_loader)
print(labels[:30], predictions[:30])
print(classification_report([labels], [predictions]))
eval_concepts(model_2, test_block_loader)
if is_validation:
  _, labels, predictions = valid(model_best, testing_loader)
  print(labels[:30], predictions[:30])
  print(classification_report([labels], [predictions]))
  conf=confusion_matrix(labels, predictions, labels=["B", "I", "O"])
  disp = ConfusionMatrixDisplay(confusion_matrix=conf, display_labels=["B", "I", "O"])
  disp.plot()
  plt.show()
  eval_concepts(model_best, test_block_loader)
  model_best.push_to_hub("AwesomeREK/concept-extraction-xlnet-early-stopping-teacher-student-self-trained")
torch.cuda.empty_cache()

# %%
model = XLNetForTokenClassification.from_pretrained("AwesomeREK/concept-extraction-reduced-distant-enhanced-early-stopping-self-trained-xlnet-model",
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
model.to(device)

# %% [markdown]
# **inference:**

# %%
sentence = "The client node in a wide area network, which connects to a router node."

inputs = tokenizer(sentence, padding='max_length', truncation=True, max_length=MAX_LEN, return_tensors="pt")

# move to gpu
ids = inputs["input_ids"].to(device)
mask = inputs["attention_mask"].to(device)
# forward pass
outputs = model(ids, mask)
logits = outputs[0]

active_logits = logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size*seq_len,) - predictions at the token level

tokens = tokenizer.convert_ids_to_tokens(ids.squeeze().tolist())
token_predictions = [id2label[i] for i in flattened_predictions.cpu().numpy()]
wp_preds = list(zip(tokens, token_predictions)) # list of tuples. Each tuple = (wordpiece, prediction)

word_level_predictions = []
for pair in wp_preds:
  if (pair[0].startswith(" ##")) or (pair[0] in [CLS_TOKEN, SEP_TOKEN, PAD_TOKEN]):
    # skip prediction
    continue
  else:
    word_level_predictions.append(pair[1])

# we join tokens, if they are not special ones
str_rep = " ".join([t[0] for t in wp_preds if t[0] not in [CLS_TOKEN, SEP_TOKEN, PAD_TOKEN]]) # .replace(" ##", "") if you want the original sentence (but wont align with labels...
print(str_rep)
print(word_level_predictions)
# Out:
# [CLS] the client node in a wide area network , which connects to a route ##r node . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ['O', 'O', 'B', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
